# %%
import os
import xml.etree.cElementTree as ET
import pprint
import re
import collections

# %%
# Data used - OpenStreep Map(OSM) -- Sunnyvale, CA
# Dataset size = 549MB

DATA = "DATA" 
SAMPLE_DATA = "data_sample.xml"

# %% [markdown]
# ### Data Wrangling Flow
# 1. Data Gathering and OSM file Preparation
# 2. Data Auditing
# 3. Data Cleaning (Quality and Tidness)
# 4. Data Analysis with SQL

# %% [markdown]
# ## Part I -- Audit and Clean the Data

# %% [markdown]
# ### 1. Data Assessment

# %%
tree = ET.parse('data_sample.xml')
root = tree.getroot()

# %%
print(root)
# Out:
# <Element 'osm' at 0x10ee989a8>

# %%
# First, I need to count unique tags in this XML file 

def count_tags(filename):
    counts = collections.defaultdict(int)
    for line in ET.iterparse(filename, events=("start",)):
        current = line[1].tag
        counts[current] += 1
    return counts

DATA_tags = count_tags(DATA)
SAMPLE_tags = count_tags(SAMPLE_DATA)
pprint.pprint(DATA_tags)
pprint.pprint(SAMPLE_tags)
# Out:
# defaultdict(<class 'int'>,
#             {'member': 40975,
#              'meta': 1,
#              'nd': 3019867,
#              'node': 2577605,
#              'note': 1,
#              'osm': 1,
#              'relation': 4361,
#              'tag': 1106609,
#              'way': 331926})
# defaultdict(<class 'int'>,
#             {'member': 581,
#              'meta': 1,
#              'nd': 543,
#              'node': 7954,
#              'note': 1,
#              'osm': 1,
#              'relation': 94,
#              'tag': 1083,
#              'way': 181})

# %% [markdown]
# ### 2. Patterns in Tags

# %%
'''
Second, I need to explore the "k" values for each tags to see if there's any variation or potential issues.
Using the provided 3 regular expressions, I will check the certain patterns in the tags. 

- "lower", for tags that contain only lowercase letters and are valid,
- "lower_colon", for otherwise valid tags with a colon in their names,
- "problemchars", for tags with problematic characters, and
- "other", for other tags that do not fall into the other three categories.
'''


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def key_type(element, keys):
    if element.tag == "tag":
        if lower.search(element.attrib['k']):
            keys['lower'] += 1
        elif lower_colon.search(element.attrib['k']):
            keys['lower_colon'] += 1
        elif problemchars.search(element.attrib['k']):
            keys['problemchars'] += 1
        else:
            keys['other'] += 1
    
    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

pprint.pprint(process_map(DATA))
# Out:
# {'lower': 691111, 'lower_colon': 398350, 'other': 17123, 'problemchars': 25}

# %% [markdown]
# ### 3. Data Quality
#
# #### Street Names Inconsistence

# %%
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road",
            "Parkway","Way","Circle","Terrace","Real","Mall","Expressway"]
# update the expected list after first runningn(add some street names, such as "Circle", "Terrace", etc.)

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")
# looking for tags which specify a street name

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = collections.defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag in["node", "way", "relation"]:
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

st_types = audit(DATA)
pprint.pprint(dict(st_types))
# Out:
# {'0.1': {'Ala 680 PM 0.1'},
#  '2': {'Showers Drive STE 2'},
#  '3': {'University Dr. Suite 3'},
#  '4A': {'Saratoga Avenue Bldg 4A'},
#  '7': {'Showers Drive STE 7'},
#  '9': {'East Charleston Road APT 9'},
#  'A': {'Lane A'},
#  'AA': {'Showers Drive BLDG AA'},
#  'Alameda': {'The Alameda'},
#  'Alley': {'Fountain Alley', 'Jackson Alley'},
#  'Ashfield': {'Ashfield'},
#  'Ave': {'Bayshore Ave',
#          'Blake Ave',
#          'Blenheim Ave',
#          'Cabrillo Ave',
#          'California Ave',
#          'E Duane Ave',
#          'Forest Ave',
#          'Greenbriar Ave',
#          'Hollenbeck Ave',
#          'Hurlingame Ave',
#          'Meridian Ave',
#          'N Blaney Ave',
#          'Portage Ave',
#          'S California Ave',
#          'Seaboard Ave',
#          'Tehama Ave',
#          'The Alameda Ave',
#          'University Ave',
#          'W Washington Ave',
#          'Walsh Ave',
#          'Westfield Ave'},
#  'Ave.': {'Hamilton Ave.', 'Menalto Ave.', 'Santa Cruz Ave.'},
#  'Axis': {'North-South Axis'},
#  'B': {'Leghorn Street #B'},
#  'Barcelona': {'Calle de Barcelona'},
#  'Bascom': {'S. Bascom'},
#  'Bay': {'Bay'},
#  'Bellomy': {'Bellomy'},
#  'Blvd': {'2501 East Bayshore Blvd',
#           'McCarthy Blvd',
#           'Mission Blvd',
#           'Mission College Blvd',
#           'N McCarthy Blvd',
#           'Pacific Commons Blvd',
#           'Stevens Creek Blvd',
#           'Warm Springs Blvd'},
#  'Broadway': {'Broadway'},
#  'Bruno': {'Serra San Bruno'},
#  'C': {'Plymouth Street #C'},
#  'CA': {'Zanker Road, San Jose, CA', 'Zanker Rd., San Jose, CA'},
#  'Calle': {'La Calle'},
#  'Center': {'Stanford Shopping Center'},
#  'Central': {'Plaza Central'},
#  'Cir': {'Celadon Cir'},
#  'Clemente': {'San Clemente'},
#  'Common': {'Potters Hatch Common'},
#  'Corners': {'Midrock Corners'},
#  'Corte': {'Bella Corte'},
#  'Creek': {'Stevens Creek'},
#  'Dr': {'1350 S Park Victoria Dr',
#         '1490 S Park Victoria Dr',
#         'Minto Dr',
#         'Oakmead Village Dr'},
#  'Dr.': {'Campus Dr.'},
#  'East': {'Northport Loop East',
#           'Park Circle East',
#           'Rio Robles East',
#           'Vanderbilt Court East'},
#  'Escarpado': {'El Escarpado'},
#  'Esplendor': {'Via Esplendor'},
#  'Esquela': {'Camina Esquela'},
#  'Evelyn': {'West Evelyn'},
#  'Franklin': {'Franklin'},
#  'Galvez': {'Galvez'},
#  'Green': {'Miranda Green'},
#  'Hamilton': {'Hamilton'},
#  'Highway': {'Monterey Highway', 'Old Bayshore Highway'},
#  'Hwy': {'Monterey Hwy'},
#  'I-280': {'Page Mill Rd @ Arastradero Rd Int S Of I-280'},
#  'Julian': {'West Julian'},
#  'Ln': {'Barber Ln'},
#  'Loop': {'Infinite Loop'},
#  'Luna': {'Calle de Luna'},
#  'Maclane': {'Maclane'},
#  'Madrid': {'Corte de Madrid'},
#  'Marino': {'Via San Marino'},
#  'Montaña': {'Vista Montaña'},
#  'Napoli': {'Via Napoli'},
#  'North': {'Plaza North', 'Magnolia Drive North', 'Walnut Circle North'},
#  'Oaks': {'North Fair Oaks', 'Waverley Oaks'},
#  'Ortega': {'Via Ortega'},
#  'Palamos': {'Via Palamos'},
#  'Paviso': {'Via Paviso'},
#  'Plaza': {'Portal Plaza', 'Rivermark Plaza'},
#  'Portofino': {'Via Portofino'},
#  'Presada': {'Paseo Presada'},
#  'Pulgas': {'Alameda de Las Pulgas'},
#  'Rd': {'Berryessa Rd',
#         'E Bayshore Rd',
#         'E Middlefield Rd',
#         'Embarcadero Rd',
#         'Sand Hill Rd',
#         'Willow Rd',
#         'Wolfe Rd'},
#  'Rhein': {'Stein Am Rhein'},
#  'Ridge': {'Roble Ridge'},
#  'Row': {'Alvarado Row', 'Santana Row'},
#  'Saratoga': {'El Paseo de Saratoga'},
#  'Seville': {'Corte de Seville'},
#  'Siding': {'Bonair Siding'},
#  'Sorrento': {'Via Sorrento'},
#  'South': {'Governors Avenue South',
#            'Magnolia Drive South',
#            'Walnut Circle South'},
#  'St': {'Monroe St', 'Ramona St', 'N 5th St', 'Casa Verde St'},
#  'Stanford': {'Stanford'},
#  'Suite': {'Stewart Drive Suite', 'West Evelyn Avenue Suite'},
#  'Ventana': {'Via Ventana'},
#  'Ventura': {'Via Ventura'},
#  'Vera': {'Villa Vera'},
#  'Village': {'Town and Country Village'},
#  'Vista': {'Villa Vista'},
#  'Volante': {'Via Volante'},
#  'Walk': {'Salvatierra Walk', 'Paseo de San Antonio Walk', 'Altaire Walk'},
#  'West': {'Campus Dr. West',
#           'Campus Drive West',
#           'Northport Loop West',
#           'Park Circle West',
#           'Vanderbilt Court West'},
#  'Winchester': {'Winchester'},
#  'ave': {'wilcox ave'},
#  'avenue': {'Santa Cruz avenue'},
#  'robles': {'rio robles'},
#  'st': {'Crane st'},
#  'street': {'N 1st street'},
#  'terrace': {'Ice House terrace'},
#  'yes': {'yes'}}

# %%
mapping = { "Ave": "Avenue",
            "Ave.": "Avenue",
            "ave": "Avenue",
            "avenue": "Avenue",
            "Blvd": "Boulevard",
            "Cir": "Circle",
            "Dr": "Drive",
            "Dr.": "Drive",
            "Rd": "Road",
            "St": "Street",
            "St.": "Street",
            "street": "Street",
            "terrace": "Terrace",
            "Hwy": "Highway",
            }

name_list = []

def audit_street_name(osmfile):
    osm_file = open(osmfile,"r")
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag in["node", "way", "relation"] :
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    new_name = update_name(tag.attrib['v'])
                    name_list.append(new_name)
                    
    osm_file.close()
    return name_list


def update_name(name):
    for n in name.split():
        if n in mapping:
            name = name.replace(n, mapping[n])
        else:
            name = name
    return name



st_name = audit_street_name(DATA)
pprint.pprint(st_name)
# Out:
# ['Knox Avenue',
#  'South Fair Oaks Avenue',
#  'West El Camino Real',
#  'West El Camino Real',
#  'East El Camino Real',
#  'East El Camino Real',
#  'East El Camino Real',
#  'Persian Drive',
#  'Halford Avenue',
#  'Halford Avenue',
#  'West El Camino Real',
#  'West El Camino Real',
#  'East El Camino Real',
#  'East Remington Drive',
#  'Hollenbeck Avenue',
#  'North 1st Street',
#  'North First Street',
#  'Leghorn Street',
#  'West Evelyn Avenue',
#  'Lagunita Drive',
#  'Stanford Avenue',
#  'Grant Road',
#  'South California Avenue',
#  'California Avenue',
#  'California Avenue',
#  'California Avenue',
#  'California Avenue',
#  'California Avenue',
#  'California Avenue',
#  'South California Avenue',
#  'South California Avenue',
#  'El Camino Real',
#  'Sunnyvale-Saratoga Road',
#  'El Camino Real',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Villa Street',
#  'Villa Street',
#  'Villa Street',
#  'East El Camino Real',
#  'East El Camino Real',
#  'South Taaffe Street',
#  'West Washington Avenue',
#  'West Evelyn Avenue',
#  'South Murphy Avenue',
#  'Fremont Avenue',
#  'East Charleston Road',
#  'North Rengstorff Avenue',
#  'Grant Road',
#  'East El Camino Real',
#  'East El Camino Real',
#  'Sheffield Avenue',
#  'Sierra Vista Avenue',
#  'Brookfield Avenue',
#  'Brookfield Avenue',
#  'Kifer Road',
#  'Covington Road',
#  'Almond Avenue',
#  'Cox Avenue',
#  'Union Avenue',
#  'San Tomas Aquino Road',
#  'University Avenue',
#  'Minnesota Avenue',
#  'University Avenue',
#  'Coleman Avenue',
#  'South Bascom Avenue',
#  'Grant Road',
#  'El Paseo de Saratoga',
#  'West Hamilton Avenue',
#  'East Hamilton Avenue',
#  'Prospect Road',
#  'North El Monte Avenue',
#  'El Monte Avenue',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'South Murphy Avenue',
#  'The Alameda',
#  'Woodberry Lane',
#  'North Shoreline Boulevard',
#  'West Hamilton Avenue',
#  'Wildwood Avenue',
#  'Main Street',
#  'El Camino Real',
#  'East Fremont Avenue',
#  'Stevens Creek Boulevard',
#  'Alameda de Las Pulgas',
#  'Middlefield Road',
#  'North Mathilda Avenue',
#  'West Maude Avenue',
#  'North Mathilda Avenue',
#  'East El Camino Real',
#  'East El Camino Real',
#  'West Maude Avenue',
#  'West Maude Avenue',
#  'South Wolfe Road',
#  'Freedom Circle',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Crane st',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'Santa Cruz Avenue',
#  'North 1st Street',
#  'South Murphy Avenue',
#  'El Camino Real',
#  'El Camino Real',
#  'Menalto Avenue',
#  'East Santa Clara Street',
#  'Altamont Circle',
#  'College Avenue',
#  'Birch Street',
#  'West San Carlos Street',
#  'East El Camino Real',
#  'West El Camino Real',
#  'The Alameda',
#  'The Alameda',
#  'El Camino Real',
#  'Stevens Creek Boulevard',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'Halford Avenue',
#  'Halford Avenue',
#  'Halford Avenue',
#  'Halford Avenue',
#  'Halford Avenue',
#  'Halford Avenue',
#  'Discovery Parkway',
#  'West El Camino Real',
#  'Lincoln Avenue',
#  'Saratoga Avenue',
#  'El Camino Real',
#  'Stanford Avenue',
#  'California Avenue',
#  'Laurelwood Road',
#  'Union Avenue',
#  'Bay',
#  'Lawrence Expressway',
#  'Kifer Road',
#  'East San Carlos Street',
#  'South 11th Street',
#  'East San Carlos Street',
#  'East San Carlos Street',
#  'Rivermark Plaza',
#  'Rivermark Plaza',
#  'East Charleston Road',
#  'Rio Robles East',
#  'Rengstorff Avenue',
#  'North De Anza Boulevard',
#  'California Avenue',
#  'El Camino Real',
#  'Portage Avenue',
#  'Portage Avenue',
#  'East Caribbean Drive',
#  'Corvin Drive',
#  'Lawrence Expressway',
#  'Lawrence Expressway',
#  'Lawrence Expressway',
#  'Lawrence Expressway',
#  'Lawrence Expressway',
#  'Lawrence Expressway',
#  'Lawrence Expressway',
#  'Lawrence Expressway',
#  'South California Avenue',
#  'California Avenue',
#  'South California Avenue',
#  'California Avenue',
#  'California Avenue',
#  'East El Camino Real',
#  'Monterey Highway',
#  'East Middlefield Road',
#  'Mission Boulevard',
#  'Mission Boulevard',
#  'Francisco Lane',
#  'Mission Boulevard',
#  'Old Middlefield Way',
#  'North Rengstorff Avenue',
#  'Stevens Creek Boulevard',
#  'McGinness Avenue',
#  'Saratoga Avenue',
#  'El Camino Real',
#  'Willow Street',
#  'South Capitol Avenue',
#  'Ansel Lane',
#  'Prospect Road',
#  'North First Street',
#  'Estancia Drive',
#  'Arastradero Road',
#  'Martin Avenue',
#  'North First Street',
#  'Lawrence Expressway',
#  'Fremont Avenue',
#  'North First Street',
#  'East El Camino Real',
#  'Component Drive',
#  'Montague Expressway',
#  'Charcot Avenue',
#  'Stevens Creek Boulevard',
#  'East Remington Drive',
#  'East Evelyn Avenue',
#  'North Rengstorff Avenue',
#  'Barber Court',
#  'Tasman Drive',
#  'Canoas Garden Avenue',
#  'Augustine Drive',
#  'El Camino Real',
#  'El Camino Real',
#  'North First Street',
#  'North First Street',
#  'Airport Parkway',
#  'Airport Parkway',
#  'Airport Parkway',
#  'Rivermark Plaza',
#  'Galvez',
#  'Galvez',
#  'Willow Road',
#  'Willow Road',
#  'East Charleston Road',
#  'Hillview Avenue',
#  'East San Carlos Street',
#  'Sunnyvale-Saratoga Road',
#  'El Camino Real',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Homestead Road',
#  'Homestead Road',
#  'Homestead Road',
#  'Moody Road',
#  'Castro Street',
#  'Castro Street',
#  'El Camino Real',
#  'Castro Street',
#  'El Camino Way',
#  'El Camino Way',
#  'Castro Street',
#  'Castro Street',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'Alameda de Las Pulgas',
#  'Lawrence Expressway',
#  'Charcot Avenue',
#  'West El Camino Real',
#  'South De Anza Boulevard',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'Castro Street',
#  'South California Avenue',
#  'California Avenue',
#  'S California Avenue',
#  'Fayette Drive',
#  'Fayette Drive',
#  'South Springer Road',
#  'Lathrop Street',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'Willow Road',
#  'California Avenue',
#  'South California Avenue',
#  'South California Avenue',
#  'South California Avenue',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'Broadway Street',
#  'Marshall Street',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'California Avenue',
#  'South California Avenue',
#  'Cambridge Avenue',
#  'Cambridge Avenue',
#  'Cambridge Avenue',
#  'Cambridge Avenue',
#  'Cambridge Avenue',
#  'Cambridge Avenue',
#  'Sheridan Avenue',
#  'Bay Road',
#  'Bay Road',
#  'Villa Street',
#  'Borregas Avenue',
#  'Main Street',
#  'Main Street',
#  'Main Street',
#  'Bay Road',
#  'Bay Road',
#  'Bay Road',
#  'Bay Road',
#  'Bay Road',
#  'Bay Road',
#  'Bay Road',
#  'Bay Road',
#  'Bay Road',
#  'Bay Road',
#  'San Antonio Road',
#  'Bay Road',
#  'Bay Road',
#  'Bay Road',
#  'Bay Road',
#  'Bay Road',
#  'Bay Road',
#  'N. Milpitas Boulevard',
#  'N. Milpitas Boulevard',
#  'High Street',
#  'High Street',
#  'Sheridan Drive',
#  'Van Buren Road',
#  'Homer Avenue',
#  'Forest Avenue',
#  'Ramona Street',
#  'Barber Court',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'El Camino Real',
#  'Creek Drive',
#  'Creek Drive',
#  'Creek Drive',
#  'Creek Drive',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Cambridge Avenue',
#  'Bay Laurel Drive',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Arbor Road',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Middle Avenue',
#  'Infinite Loop',
#  'Birch Street',
#  'Birch Street',
#  'Birch Street',
#  'Birch Street',
#  'Birch Street',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'Lambert Avenue',
#  'Wilkie Way',
#  'Del Medio Avenue',
#  'West El Camino Real',
#  'West El Camino Real',
#  'Emerson Street',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'Bryant Street',
#  'Bryant Street',
#  'Cowper Street',
#  'Hamilton Avenue',
#  'North Abel Street',
#  'Middlefield Road',
#  'Bryant Street',
#  'Plaza North',
#  'El Camino Real',
#  'California Avenue',
#  'California Avenue',
#  'South California Avenue',
#  'California Avenue',
#  'California Avenue',
#  'South California Avenue',
#  'South California Avenue',
#  'Ash Street',
#  'Calabazas Creek Circle',
#  'South Murphy Avenue',
#  'Cabrillo Avenue',
#  'Saratoga Avenue',
#  'Castro Street',
#  'Old Middlefield Way',
#  'Hillview Avenue',
#  'Hillview Avenue',
#  'West Middlefield Road',
#  'Victory Avenue',
#  'Olin Avenue',
#  'Santana Row',
#  'Santana Row',
#  'Grant Road',
#  'Grant Road',
#  'East El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Grant Road',
#  'East Evelyn Avenue',
#  'South Murphy Avenue',
#  'Newell Road',
#  'Newell Road',
#  'Middlefield Road',
#  'View Street',
#  'Showers Drive',
#  'Miramonte Avenue',
#  'Miramonte Avenue',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'North Rengstorff Avenue',
#  'El Camino Real',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'wilcox Avenue',
#  'Sunnyvale-Saratoga Road',
#  'Sunnyvale-Saratoga Road',
#  'East El Camino Real',
#  'South Murphy Avenue',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Darya Court',
#  'Parvin Drive',
#  'Parvin Drive',
#  'Parvin Drive',
#  'East Charleston Road',
#  'East El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'North Wolfe Road',
#  'Stevens Creek Boulevard',
#  'Lathrop Street',
#  'El Camino Real',
#  'El Camino Real',
#  'Lathrop Street',
#  'El Camino Real',
#  'Lathrop Street',
#  'Everett Avenue',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'South Third Street',
#  'North San Pedro Street',
#  'Ranch Drive',
#  'Barber Lane',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Bellomy',
#  'Woodside Road',
#  'Woodside Road',
#  'Hazel Avenue',
#  'Hazel Avenue',
#  'Hazel Avenue',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'Mission College Boulevard',
#  'Addison Avenue',
#  'Willow Street',
#  'Willow Street',
#  'El Camino Real',
#  'S California Avenue',
#  'Willow Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'South California Avenue',
#  'California Avenue',
#  'South California Avenue',
#  'S California Avenue',
#  'California Avenue',
#  'California Avenue',
#  'South California Avenue',
#  'South California Avenue',
#  'California Avenue',
#  'South California Avenue',
#  'California Avenue',
#  'South California Avenue',
#  'South California Avenue',
#  'South California Avenue',
#  'Grant Road',
#  'California Avenue',
#  'Miramonte Avenue',
#  'California Avenue',
#  'Alpine Road',
#  'Alpine Road',
#  'Alpine Road',
#  'Alpine Road',
#  'Page Mill Road',
#  'South California Avenue',
#  'South California Avenue',
#  'California Avenue',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'El Camino Real',
#  'Alpine Road',
#  'Alpine Road',
#  'Alpine Road',
#  'Alpine Road',
#  'Alpine Road',
#  'Alpine Road',
#  'Alpine Road',
#  'Alpine Road',
#  'Alpine Road',
#  'Alpine Road',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'Town and Country Village',
#  'North 1st Street',
#  'El Camino Real',
#  'El Camino Real',
#  'El Camino Real',
#  'S California Avenue',
#  'S California Avenue',
#  'S California Avenue',
#  'South California Avenue',
#  'S California Avenue',
#  'South California Avenue',
#  'South California Avenue',
#  'South 3rd Street',
#  'South 1st Street',
#  'Main Street',
#  'State Street',
#  'El Camino Real',
#  'West El Camino Real',
#  'South Bernardo Avenue',
#  'South Bernardo Avenue',
#  'South Bernardo Avenue',
#  'South Bernardo Avenue',
#  'South Bernardo Avenue',
#  'South Bernardo Avenue',
#  'South Bernardo Avenue',
#  'South Bernardo Avenue',
#  'South Bernardo Avenue',
#  'South Bernardo Avenue',
#  'South Bernardo Avenue',
#  'Sand Hill Road',
#  'Sand Hill Road',
#  'Via Ortega Drive',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Portage Avenue',
#  'Portage Avenue',
#  'Portage Avenue',
#  'Portage Avenue',
#  'Stevens Creek Boulevard',
#  'Monte Rosa Drive',
#  'North Rengstorff Avenue',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'San Antonio Road',
#  'San Antonio Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'Woodside Road',
#  'North San Antonio Road',
#  'Woodside Road',
#  'Woodside Road',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'Kifer Road',
#  'Commercial Street',
#  'Commercial Street',
#  'East Arques Avenue',
#  'Kifer Road',
#  'Kifer Road',
#  'Commercial Street',
#  'Kifer Road',
#  'Commercial Street',
#  'Commercial Street',
#  'Commercial Street',
#  'Commercial Street',
#  'Commercial Street',
#  'Commercial Street',
#  'De Guigne Drive',
#  'De Guigne Drive',
#  'De Guigne Drive',
#  'East California Avenue',
#  'Thompson Place',
#  'Kifer Road',
#  'Commercial Street',
#  'Kifer Road',
#  'Commercial Street',
#  'Kifer Road',
#  'Commercial Street',
#  'Kifer Road',
#  'Commercial Street',
#  'Commercial Street',
#  'Alvarado Avenue',
#  'Alvarado Avenue',
#  'Alvarado Avenue',
#  'Alvarado Avenue',
#  'Alvarado Avenue',
#  'Alvarado Avenue',
#  'Alvarado Avenue',
#  'San Juan Drive',
#  'Johanna Avenue',
#  'Lawrence Expressway',
#  'Stewart Drive',
#  'Stewart Drive',
#  'Stewart Drive',
#  'East Evelyn Avenue',
#  'East Ahwanee Avenue',
#  'East Ahwanee Avenue',
#  'East Ahwanee Avenue',
#  'East Ahwanee Avenue',
#  'North Fair Oaks Avenue',
#  'Santa Rita Street',
#  'East Duane Avenue',
#  'East Duane Avenue',
#  'East Arques Avenue',
#  'Kern Avenue',
#  'Lawrence Expressway',
#  'Lawrence Expressway',
#  'East Duane Avenue',
#  'East Duane Avenue',
#  'Santa Rosalia Terrace',
#  'Santa Rosalia Terrace',
#  'Fontana Terrace',
#  'Fontana Terrace',
#  'Fontana Terrace',
#  'Kern Avenue',
#  'Kern Avenue',
#  'Kern Avenue',
#  'Kern Avenue',
#  'Rivermark Plaza',
#  'Minto Drive',
#  'Jackson Street',
#  'Mission Boulevard',
#  'Ranch Drive',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'El Camino Real',
#  'South Wolfe Road',
#  'North El Monte Avenue',
#  'Rich Avenue',
#  'West El Camino Real',
#  'South Wolfe Road',
#  'South Wolfe Road',
#  'South Wolfe Road',
#  'South Wolfe Road',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'Los Altos Avenue',
#  'N Wolfe Road',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'East Duane Avenue',
#  'East Duane Avenue',
#  'East Duane Avenue',
#  'Leghorn Street',
#  'Stevens Creek Boulevard',
#  'De La Cruz Boulevard',
#  'East El Camino Real',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Calabazas Creek Circle',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Way',
#  'Longfellow Court',
#  'Longfellow Court',
#  'Longfellow Court',
#  'Longfellow Court',
#  'Longfellow Court',
#  'Longfellow Court',
#  'Longfellow Court',
#  'Longfellow Court',
#  'Longfellow Court',
#  'Park Boulevard',
#  'Alma Street',
#  'Alma Street',
#  'Stevens Creek Boulevard',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'Bella Corte',
#  'South De Anza Boulevard',
#  'Bayshore Parkway',
#  'North Rengstorff Avenue',
#  'North San Antonio Road',
#  'South Bascom Avenue',
#  'Rolison Road',
#  'Mission College Boulevard',
#  'El Camino Real',
#  'Saratoga Avenue',
#  'Kyle Park Court',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'Barber Lane',
#  'West El Camino Real',
#  'North Mary Avenue',
#  'North Mary Avenue',
#  'Saratoga Avenue',
#  'Cox Avenue',
#  'North Mary Avenue',
#  'San Antonio Road',
#  'Cox Avenue',
#  'Cox Avenue',
#  'Moorpark Avenue',
#  'Park Avenue',
#  'Metro Drive',
#  'El Camino Real',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'Broadway',
#  'East Duane Avenue',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Villa Street',
#  'Castro Street',
#  'Villa Street',
#  'Hope Street',
#  'Grant Road',
#  'Moffett Boulevard',
#  'Moffett Boulevard',
#  'Castro Street',
#  'Castro Street',
#  'Third Street',
#  'W El Camino Real',
#  'West El Camino Real',
#  'Prospect Road',
#  'Saratoga Avenue',
#  'Prospect Road',
#  'Prospect Road',
#  'Saratoga Avenue',
#  'Prospect Road',
#  'East El Camino Real',
#  'Infinite Loop',
#  'Walsh Avenue',
#  'Castro Street',
#  'Pear Avenue',
#  'Amphitheatre Parkway',
#  'Santana Row',
#  'East El Camino Real',
#  'Grant Road',
#  'West Evelyn Avenue',
#  'West Evelyn Avenue',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'Homestead Road',
#  'Homestead Road',
#  'West El Camino Real',
#  'View Street',
#  'Dana Street',
#  'Dana Street',
#  'Dana Street',
#  'Castro Street',
#  'Castro Street',
#  'Dana Street',
#  'The Alameda',
#  'The Alameda',
#  'The Alameda',
#  'Prospect Road',
#  'Castro Street',
#  'Castro Street',
#  'Castro Street',
#  'W El Camino Real',
#  'South Mathilda Avenue',
#  'South Mathilda Avenue',
#  'South Mathilda Avenue',
#  'South Mathilda Avenue',
#  'South Mathilda Avenue',
#  'South Mathilda Avenue',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'Aries Way',
#  'Altair Way',
#  'Altair Way',
#  'Altair Way',
#  'Altair Way',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'South Murphy Avenue',
#  'Charles Street',
#  'Charles Street',
#  'Charles Street',
#  'Charles Street',
#  'Charles Street',
#  'Charles Street',
#  'Charles Street',
#  'Charles Street',
#  'Saratoga Avenue',
#  'South Pastoria Avenue',
#  'Waverly Street',
#  'Florence Street',
#  'Florence Street',
#  'Waverly Street',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'Sutter Avenue',
#  'West Washington Avenue',
#  'Coolidge Avenue',
#  'Florence Street',
#  'Waverly Street',
#  'Waverly Street',
#  'Florence Street',
#  'Waverly Street',
#  'Florence Street',
#  'Waverly Street',
#  'Florence Street',
#  'South Pastoria Avenue',
#  'South Pastoria Avenue',
#  'Waverly Street',
#  'Waverly Street',
#  'Florence Street',
#  'Florence Street',
#  'West McKinley Avenue',
#  'West McKinley Avenue',
#  'South Mathilda Avenue',
#  'South Mathilda Avenue',
#  'Waverly Street',
#  'Waverly Street',
#  'Florence Street',
#  'Florence Street',
#  'Florence Street',
#  'Waverly Street',
#  'Waverly Street',
#  'Florence Street',
#  'Pala Avenue',
#  'Peralta Avenue',
#  'Purissima Avenue',
#  'Pala Avenue',
#  'Peralta Avenue',
#  'Rincon Avenue',
#  'Rincon Avenue',
#  'Purissima Avenue',
#  'Pala Avenue',
#  'Peralta Avenue',
#  'Pala Avenue',
#  'Purissima Avenue',
#  'Rincon Avenue',
#  'Purissima Avenue',
#  'Rincon Avenue',
#  'Peralta Avenue',
#  'Sutter Avenue',
#  'Portage Avenue',
#  'Hollenbeck Avenue',
#  'Hollenbeck Avenue',
#  'Hollenbeck Avenue',
#  'Hollenbeck Avenue',
#  'South Mathilda Avenue',
#  'South Mathilda Avenue',
#  'South Mathilda Avenue',
#  'South Mathilda Avenue',
#  'Walnut Street',
#  'Walnut Street',
#  'Walnut Street',
#  'Walnut Street',
#  'Broadway',
#  'Montague Expressway',
#  'Grant Road',
#  'Grant Road',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'West El Camino Real',
#  'South Taaffe Street',
#  'South Sunnyvale Avenue',
#  'South Sunnyvale Avenue',
#  'South Taaffe Street',
#  'South Sunnyvale Avenue',
#  'South Sunnyvale Avenue',
#  'South Murphy Avenue',
#  'South Sunnyvale Avenue',
#  'South Sunnyvale Avenue',
#  'South Sunnyvale Avenue',
#  'South Sunnyvale Avenue',
#  'South Murphy Avenue',
#  'North Taaffe Street',
#  'North Frances Street',
#  'North Taaffe Street',
#  'North Frances Street',
#  'North Taaffe Street',
#  'North Taaffe Street',
#  'North Frances Street',
#  'North Frances Street',
#  'North Taaffe Street',
#  'North Taaffe Street',
#  'West Hendy Avenue',
#  'Beemer Avenue',
#  'West Hendy Avenue',
#  'Angel Avenue',
#  'Angel Avenue',
#  'Beemer Avenue',
#  'Angel Avenue',
#  'Angel Avenue',
#  'Beemer Avenue',
#  'Beemer Avenue',
#  'Christy Street',
#  'Boscell Road',
#  'Marsh Road',
#  'North Frances Street',
#  'North Frances Street',
#  'North Frances Street',
#  'North Frances Street',
#  'Mission College Boulevard',
#  'Page Mill Road',
#  'San Antonio Road',
#  'South 1st Street',
#  'Paseo de San Antonio Walk',
#  'North Sunnyvale Avenue',
#  'North Sunnyvale Avenue',
#  'Hollenbeck Avenue',
#  'Hollenbeck Avenue',
#  'Hollenbeck Avenue',
#  'Sunset Avenue',
#  'Sunset Avenue',
#  'Sunset Avenue',
#  'Sunset Avenue',
#  'Sunset Avenue',
#  'Sunset Avenue',
#  'Sunset Avenue',
#  'Sunset Avenue',
#  'Sunset Avenue',
#  'Sunset Avenue',
#  'Coolidge Avenue',
#  'Lewis Avenue',
#  'Muender Avenue',
#  'Muender Avenue',
#  'West Evelyn Avenue',
#  'Lewis Avenue',
#  'West Evelyn Avenue',
#  'Muender Avenue',
#  'Muender Avenue',
#  'Lewis Avenue',
#  'Coolidge Avenue',
#  'Lewis Avenue',
#  'Coolidge Avenue',
#  'West Washington Avenue',
#  'Carson Drive',
#  'West Evelyn Avenue',
#  'Carson Drive',
#  'West Washington Avenue',
#  'Crawford Drive',
#  'Crawford Drive',
#  'Piedra Drive',
#  'South Mary Avenue',
#  'Piedra Drive',
#  'Piedra Drive',
#  'Piedra Drive',
#  'Matadero Drive',
#  'Piedra Drive',
#  'Piedra Drive',
#  'Matadero Drive',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'Matadero Drive',
#  'Matadero Drive',
#  'South Mary Avenue',
#  'Bidwell Avenue',
#  'Carson Drive',
#  'Carson Drive',
#  'Bidwell Avenue',
#  'Carson Drive',
#  'Carson Drive',
#  'West Washington Avenue',
#  'West Washington Avenue',
#  'Bidwell Avenue',
#  'Carson Drive',
#  'Bidwell Avenue',
#  'Carson Drive',
#  'Crawford Drive',
#  'Crawford Drive',
#  'West Washington Avenue',
#  'Hacker Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Brahms Way',
#  'Cumulus Avenue',
#  'Cirrus Avenue',
#  'Cirrus Avenue',
#  'Cumulus Avenue',
#  'Cirrus Avenue',
#  'Cirrus Avenue',
#  'Cirrus Avenue',
#  'Cirrus Avenue',
#  'Cirrus Avenue',
#  'Cirrus Avenue',
#  'Cirrus Avenue',
#  'Cirrus Avenue',
#  'Cirrus Avenue',
#  'Cirrus Avenue',
#  'Cirrus Avenue',
#  'Goya Drive',
#  'Cezanne Drive',
#  'Cezanne Drive',
#  'Azure Street',
#  'Cezanne Drive',
#  'Azure Street',
#  'Cezanne Drive',
#  'Cezanne Drive',
#  'Azure Street',
#  'Cezanne Drive',
#  'Azure Street',
#  'Azure Street',
#  'Azure Street',
#  'Azure Street',
#  'Azure Street',
#  'Azure Street',
#  'Azure Street',
#  'Azure Street',
#  'Zanker Road',
#  'North Wolfe Road',
#  'Morse Avenue',
#  'Saratoga Avenue',
#  'Welch Road',
#  'West Olive Avenue',
#  'West Olive Avenue',
#  'West Olive Avenue',
#  'Clarence Avenue',
#  'South Mary Avenue',
#  'Dennis Avenue',
#  'Sara Avenue',
#  'Dennis Avenue',
#  'Sara Avenue',
#  'Clarence Avenue',
#  'Sunset Avenue',
#  'South Mary Avenue',
#  'Molino Avenue',
#  'South Mary Avenue',
#  'Molino Avenue',
#  'West Iowa Avenue',
#  'West Iowa Avenue',
#  'West Iowa Avenue',
#  'Sutter Avenue',
#  'West Iowa Avenue',
#  'West Iowa Avenue',
#  'Sutter Avenue',
#  'West Iowa Avenue',
#  'Sunset Avenue',
#  'Sara Avenue',
#  'Sara Avenue',
#  'Sara Avenue',
#  'Sara Avenue',
#  'Clarence Avenue',
#  'Clarence Avenue',
#  'Dennis Avenue',
#  'Dennis Avenue',
#  'West McKinley Avenue',
#  'West McKinley Avenue',
#  'Ositos Avenue',
#  'Ositos Avenue',
#  'Ositos Avenue',
#  'Ositos Avenue',
#  'Nuestra Avenue',
#  'Nuestra Avenue',
#  'Nuestra Avenue',
#  'Nuestra Avenue',
#  'Novato Avenue',
#  'Novato Avenue',
#  'Novato Avenue',
#  'Novato Avenue',
#  'Molino Avenue',
#  'Molino Avenue',
#  'Redondo Terrace',
#  'Redondo Terrace',
#  'Redondo Terrace',
#  'Redondo Terrace',
#  'Redondo Terrace',
#  'Pismo Terrace',
#  'Pismo Terrace',
#  'Pismo Terrace',
#  'Pismo Terrace',
#  'Pescadero Terrace',
#  'Pescadero Terrace',
#  'Kearny Terrace',
#  'Kearny Terrace',
#  'Pescadero Terrace',
#  'Pescadero Terrace',
#  'Markham Terrace',
#  'Markham Terrace',
#  'Brookline Drive',
#  'Brookline Drive',
#  'Quetta Avenue',
#  'Blair Court',
#  'Blair Court',
#  'Stevens Creek Boulevard',
#  'Prunelle Court',
#  'W. El Camino Real',
#  'Page Mill Road',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'Bay Road',
#  'Loma Verde Avenue',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Price Court',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Loma Verde Avenue',
#  'Layne Court',
#  'Loma Verde Avenue',
#  'Layne Court',
#  'Loma Verde Avenue',
#  'Layne Court',
#  'Loma Verde Avenue',
#  'Layne Court',
#  'Loma Verde Avenue',
#  'Layne Court',
#  'Loma Verde Avenue',
#  'Layne Court',
#  'Layne Court',
#  'Layne Court',
#  'Loma Verde Avenue',
#  'Layne Court',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Tahoe Lane',
#  'Tahoe Lane',
#  'Donner Lane',
#  'Almanor Lane',
#  'Almanor Lane',
#  'West Bayshore Road',
#  'Louis Road',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Berryessa Street',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'Loma Verde Place',
#  'East Bayshore Road',
#  'West Bayshore Road',
#  'Fallen Leaf Street',
#  'Berryessa Street',
#  'East Bayshore Road',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Loma Verde Avenue',
#  'Colorado Avenue',
#  'Colorado Avenue',
#  'Colorado Avenue',
#  'Colorado Avenue',
#  'Colorado Avenue',
#  'Colorado Avenue',
#  'Colorado Avenue',
#  'Colorado Avenue',
#  'Colorado Avenue',
#  'Amarillo Avenue',
#  'Amarillo Avenue',
#  'Amarillo Avenue',
#  'Amarillo Avenue',
#  'Amarillo Avenue',
#  'Amarillo Avenue',
#  'Amarillo Avenue',
#  'Amarillo Avenue',
#  'Amarillo Avenue',
#  'Amarillo Avenue',
#  'Colorado Avenue',
#  'West Bayshore Road',
#  'West Bayshore Road',
#  'West Bayshore Road',
#  'West Bayshore Road',
#  'East Bayshore Road',
#  'East Bayshore Road',
#  'East Bayshore Road',
#  'West Greenwich Place',
#  'East Greenwich Place',
#  'Oregon Avenue',
#  'Embarcadero Road',
#  'Middlefield Road',
#  'Embarcadero Road',
#  'Heather Lane',
#  'North California Avenue',
#  'Primrose Way',
#  'Wildwood Lane',
#  'Parkinson Avenue',
#  'Newell Road',
#  'Walnut Drive',
#  'Melville Avenue',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Lincoln Avenue',
#  'Arcadia Place',
#  'Island Drive',
#  'Channing Avenue',
#  'Southwood Drive',
#  'Rhodes Drive',
#  'Center Drive',
#  'Lincoln Avenue',
#  'Forest Avenue',
#  'Fife Avenue',
#  'Boyce Avenue',
#  'Boyce Avenue',
#  'Boyce Avenue',
#  'Boyce Avenue',
#  'Boyce Avenue',
#  'Lincoln Avenue',
#  'Lincoln Avenue',
#  'Lincoln Avenue',
#  'Guinda Street',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Fulton Street',
#  'Guinda Street',
#  'Fulton Street',
#  'Middlefield Road',
#  'Guinda Street',
#  'Fulton Street',
#  'Guinda Street',
#  'Middlefield Road',
#  'Guinda Street',
#  'Hale Street',
#  'Homer Avenue',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'Middlefield Road',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'Seneca Street',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'Hamilton Avenue',
#  'University Avenue',
#  'University Avenue',
#  'Middlefield Road',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'Forest Avenue',
#  'Forest Avenue',
#  'Forest Avenue',
#  'Forest Avenue',
#  'University Avenue',
#  'San Antonio Avenue',
#  'Elwell Court',
#  'Elwell Court',
#  'Elwell Court',
#  'Elwell Court',
#  'Elwell Court',
#  'Elwell Court',
#  'Elwell Court',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'Fabian Way',
#  'Alma Street',
#  'Alma Street',
#  'Duncan Place',
#  'Fabian Way',
#  'Middlefield Road',
#  'Fabian Way',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'East Bayshore Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'East Bayshore Road',
#  'East Bayshore Road',
#  'East Bayshore Road',
#  'East Bayshore Road',
#  'Fabian Way',
#  'Transport Street',
#  'San Antonio Avenue',
#  'Transport Street',
#  'Transport Street',
#  'Transport Street',
#  'Transport Street',
#  'Transport Street',
#  'Transport Street',
#  'Transport Street',
#  'Transport Street',
#  'Transport Street',
#  'Transport Street',
#  'Transport Street',
#  'Transport Street',
#  'Transport Street',
#  'Alma Street',
#  'Ponce Drive',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'East Charleston Road',
#  'San Antonio Avenue',
#  'Altaire Walk',
#  'Altaire Walk',
#  'Altaire Walk',
#  'Altaire Walk',
#  'Altaire Walk',
#  'Altaire Walk',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'Commercial Street',
#  'Commercial Street',
#  'Federation Way',
#  'Commercial Street',
#  'Commercial Street',
#  'East Charleston Road',
#  'San Antonio Avenue',
#  'Industrial Avenue',
#  'Industrial Avenue',
#  'San Antonio Avenue',
#  'Industrial Avenue',
#  'Industrial Avenue',
#  'Industrial Avenue',
#  'Commercial Street',
#  'Industrial Avenue',
#  'Industrial Avenue',
#  'Commercial Street',
#  'Commercial Street',
#  'Industrial Avenue',
#  'Industrial Avenue',
#  'Commercial Street',
#  'Industrial Avenue',
#  'Industrial Avenue',
#  'Industrial Avenue',
#  'Industrial Avenue',
#  'Industrial Avenue',
#  'Industrial Avenue',
#  'Commercial Street',
#  'Charleston Road',
#  'Industrial Avenue',
#  'Commercial Street',
#  'Industrial Avenue',
#  'Commercial Street',
#  'Commercial Street',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'San Antonio Avenue',
#  'Charleston Road',
#  'Charleston Road',
#  'South Court',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'East Meadow Drive',
#  'East Meadow Drive',
#  'The Alameda',
#  'The Alameda',
#  'El Carmelo Avenue',
#  'Colorado Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Dorado Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Dorado Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'El Carmelo Avenue',
#  'High Street',
#  'High Street',
#  'High Street',
#  'El Carmelo Avenue',
#  'High Street',
#  'High Street',
#  'Bryant Street',
#  'High Street',
#  'El Carmelo Avenue',
#  'High Street',
#  'High Street',
#  'El Carmelo Avenue',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Middlefield Road',
#  'Alma Street',
#  'Alma Street',
#  'Middlefield Road',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Middlefield Road',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Alma Street',
#  'Alma Street',
#  'South Court',
#  'Middlefield Road',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Midtown Court',
#  'Alma Street',
#  'Alma Street',
#  'Middlefield Road',
#  'Alma Street',
#  'Middlefield Road',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Middlefield Road',
#  'Alma Street',
#  'Byron Street',
#  'Midtown Court',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Alma Street',
#  'Byron Street',
#  'Byron Street',
#  'Byron Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Byron Street',
#  'Alma Street',
#  'Byron Street',
#  'Byron Street',
#  'Alma Street',
#  'Middlefield Road',
#  'Alma Street',
#  'Middlefield Road',
#  'Alma Street',
#  'Alma Street',
#  'Gaspar Court',
#  'Middlefield Road',
#  'Alma Street',
#  'Randers Court',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Randers Court',
#  'Middlefield Road',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Bryant Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'El Dorado Avenue',
#  'Alma Street',
#  'Alma Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Loma Verde Avenue',
#  'Emerson Street',
#  'Emerson Street',
#  'Cowper Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Waverley Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Alma Street',
#  'Emerson Street',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Colorado Avenue',
#  'Marion Avenue',
#  'Colorado Avenue',
#  'Oregon Avenue',
#  'Oregon Avenue',
#  'Oregon Avenue',
#  'Oregon Avenue',
#  'Oregon Avenue',
#  'Oregon Avenue',
#  'Towle Way',
#  'Towle Way',
#  'Colorado Avenue',
#  'Towle Way',
#  'Towle Way',
#  'Towle Way',
#  'Towle Way',
#  'Towle Way',
#  'Towle Way',
#  'Clara Drive',
#  'Colorado Avenue',
#  'Clara Drive',
#  'Colorado Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Colorado Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Colorado Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Ellsworth Place',
#  'Colorado Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Colorado Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Colorado Avenue',
#  'Sutter Avenue',
#  'San Carlos Court',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Colorado Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Sutter Avenue',
#  'Colorado Avenue',
#  'Colorado Avenue',
#  'South Bayview Avenue',
#  'East Evelyn Avenue',
#  'Cowper Street',
#  'Middlefield Road',
#  'Webster Street',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Byron Street',
#  'Webster Street',
#  'Tasso Street',
#  'Channing Avenue',
#  'Addison Avenue',
#  'Channing Avenue',
#  'Addison Avenue',
#  'Channing Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Addison Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Addison Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Homer Avenue',
#  'Addison Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Homer Avenue',
#  'Addison Avenue',
#  'Homer Avenue',
#  'Addison Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Addison Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Addison Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Addison Avenue',
#  'Forest Avenue',
#  'Channing Avenue',
#  'Lincoln Avenue',
#  'Channing Avenue',
#  'Homer Avenue',
#  'Forest Avenue',
#  'Addison Avenue',
#  'Channing Avenue',
#  'Addison Avenue',
#  'Forest Avenue',
#  'Addison Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Middlefield Road',
#  'Addison Avenue',
#  'Forest Avenue',
#  'Melville Avenue',
#  'Middlefield Road',
#  'Forest Avenue',
#  'Melville Avenue',
#  'Channing Avenue',
#  'Middlefield Road',
#  'Addison Avenue',
#  'Forest Avenue',
#  'Middlefield Road',
#  'Forest Avenue',
#  'Channing Avenue',
#  'Middlefield Road',
#  'Addison Avenue',
#  'Forest Avenue',
#  'Forest Avenue',
#  'Middlefield Road',
#  'Forest Avenue',
#  'Channing Avenue',
#  'Addison Avenue',
#  'Forest Avenue',
#  'Forest Avenue',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Addison Avenue',
#  'Forest Avenue',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Addison Avenue',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Homer Avenue',
#  'Addison Avenue',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Hamilton Avenue',
#  'Addison Avenue',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Hamilton Avenue',
#  'Homer Avenue',
#  'Forest Avenue',
#  'Hamilton Avenue',
#  'Homer Avenue',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Hamilton Avenue',
#  'Homer Avenue',
#  'Webster Street',
#  'Homer Avenue',
#  'Forest Avenue',
#  'Hamilton Avenue',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Hamilton Avenue',
#  'Homer Avenue',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Hamilton Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Webster Street',
#  'Channing Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Cowper Street',
#  'Forest Avenue',
#  'Melville Avenue',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Hamilton Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Cowper Street',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Cowper Street',
#  'Forest Avenue',
#  'Channing Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Cowper Street',
#  'Homer Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Cowper Street',
#  'Channing Avenue',
#  'Hamilton Avenue',
#  'Homer Avenue',
#  'Forest Avenue',
#  'Hamilton Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Cowper Street',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Hamilton Avenue',
#  'Channing Avenue',
#  'Cowper Street',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Cowper Street',
#  'Hamilton Avenue',
#  'Homer Avenue',
#  'Channing Avenue',
#  'Cowper Street',
#  'Forest Avenue',
#  'Hamilton Avenue',
#  'Webster Street',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Forest Avenue',
#  'Hamilton Avenue',
#  'Webster Street',
#  'Forest Avenue',
#  'Homer Avenue',
#  'Webster Street',
#  'Channing Avenue',
#  'Hamilton Avenue',
#  'Homer Avenue',
#  'Webster Street',
#  'Channing Avenue',
#  'Cowper Street',
#  'Channing Avenue',
#  'Cowper Street',
#  'Channing Avenue',
#  'Channing Avenue',
#  'Webster Street',
#  'Webster Street',
#  'Cowper Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Middlefield Road',
#  'Webster Street',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Middlefield Road',
#  'Webster Street',
#  'Webster Street',
#  'Cowper Street',
#  'Cowper Street',
#  'Cowper Street',
#  'Cowper Street',
#  'Cowper Street',
#  'Webster Street',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Webster Street',
#  'Cowper Street',
#  'Webster Street',
#  'Cowper Street',
#  'Webster Street',
#  'Cowper Street',
#  'Middlefield Road',
#  'Webster Street',
#  'Cowper Street',
#  'Webster Street',
#  'Webster Street',
#  'Cowper Street',
#  'Webster Street',
#  'Cowper Street',
#  'Webster Street',
#  'Webster Street',
#  'Cowper Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Middlefield Road',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Cowper Street',
#  'Webster Street',
#  'Webster Street',
#  'Cowper Street',
#  'Middlefield Road',
#  'Cowper Street',
#  'Webster Street',
#  'Cowper Street',
#  'Middlefield Road',
#  'Webster Street',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Webster Street',
#  'Cowper Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Cowper Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Webster Street',
#  'Cowper Street',
#  'Waverley Street',
#  'Channing Avenue',
#  'Addison Avenue',
#  'Embarcadero Road',
#  'Addison Avenue',
#  'Addison Avenue',
#  'Addison Avenue',
#  'Addison Avenue',
#  'Addison Avenue',
#  'Addison Avenue',
#  'Addison Avenue',
#  'Addison Avenue',
#  'Addison Avenue',
#  'Addison Avenue',
#  'Addison Avenue',
#  'Addison Avenue',
#  'Cowper Street',
#  'Cowper Street',
#  'Kipling Street',
#  'Cowper Street',
#  'Kipling Street',
#  'Kipling Street',
#  'Kipling Street',
#  'Cowper Street',
#  'Kipling Street',
# ...
#  'Oak Grove Drive',
#  'Oak Grove Drive',
#  'Oak Grove Drive',
#  'Oak Grove Drive',
#  'Oak Grove Drive',
#  'Oak Grove Drive',
#  'River Side Court',
#  'Crandall Circle',
#  'Latham Street',
#  'Latham Street',
#  'West El Camino Real',
#  'Halford Avenue',
#  'Birchwood Drive',
#  'Birchwood Drive',
#  'Renaissance Drive',
#  'Renaissance Drive',
#  'Renaissance Drive',
#  'Renaissance Drive',
#  'Renaissance Drive',
#  'Renaissance Drive',
#  'North 1st Street',
#  'Vista Montaña',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Windsor Way',
#  'Wagner Avenue',
#  'Burgoyne Street',
#  'Burgoyne Street',
#  'North Rengstorff Avenue',
#  'Renaissance Drive',
#  'Renaissance Drive',
#  'Sunrise Drive',
#  'Zanker Road',
#  'Los Esteros Road',
#  'Gold Street',
#  'Gold Street',
#  'Alderbrook Lane',
#  'Wilson Way',
#  'Del Medio Avenue',
#  'Fordham Drive',
#  'El Camino Real',
#  'Jackson Street',
#  'El Camino Real',
#  'El Camino Real',
#  'Morse Street',
#  'Douglane Avenue',
#  'Douglane Avenue',
#  'Douglane Avenue',
#  'Douglane Avenue',
#  'West Hamilton Avenue',
#  'West Hamilton Avenue',
#  'West Hamilton Avenue',
#  'West Hamilton Avenue',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Clarita Avenue',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'Bismarck Drive',
#  'West Hamilton Avenue',
#  'West Hamilton Avenue',
#  'Ryland Street',
#  'Ryland Street',
#  'Lomita Drive',
#  'Carola Avenue',
#  'Carola Avenue',
#  'Carola Avenue',
#  'Innovation Way',
#  'North 1st Street',
#  'North Pastoria Avenue',
#  'North Mathilda Avenue',
#  'North San Pedro Street',
#  'Ryland Street',
#  'The Alameda',
#  'West Middlefield Road',
#  'Dale Avenue',
#  'Pear Avenue',
#  'West El Camino Real',
#  'Matrix Boulevard',
#  'North 4th Street',
#  'Hillview Avenue',
#  'El Dorado Street',
#  'West San Carlos Street',
#  'Bair Island Road',
#  'Casa Verde Street',
#  'Casa Verde Street',
#  'Casa Verde Street',
#  'America Center Drive',
#  'America Center Drive',
#  'America Center Court',
#  'rio robles',
#  'Race Street',
#  'Crescent Village Circle',
#  'North 9th Street',
#  'North 9th Street',
#  'North 9th Street',
#  'North 9th Street',
#  'North 9th Street',
#  'North 9th Street',
#  'Fremont Boulevard',
#  'Coleman Avenue',
#  'Danromas Way',
#  'North 9th Street',
#  'North 9th Street',
#  'North 9th Street',
#  'North 9th Street',
#  'North 9th Street',
#  'North 9th Street',
#  'North 9th Street',
#  'North 9th Street',
#  'North 9th Street',
#  'West Calaveras Boulevard',
#  'Bigoak Drive',
#  'Big Oak Drive',
#  'Bigoak Drive',
#  'Bigoak Drive',
#  'Bigoak Drive',
#  'Bigoak Drive',
#  'Oaktree Drive',
#  'Bigoak Court',
#  'Bigoak Drive',
#  'Oaktree Drive',
#  'Oaktree Drive',
#  'Oaktree Drive',
#  'Oaktree Drive',
#  'Bigoak Court',
#  'Bigoak Court',
#  'Bigoak Court',
#  'Bigoak Court',
#  'Bigoak Court',
#  'Bigoak Court',
#  'Bigoak Court',
#  'Bigoak Court',
#  'Bigoak Court',
#  'Bigoak Court',
#  'Bigoak Court',
#  'Oaktree Drive',
#  'Oaktree Drive',
#  'Oaktree Drive',
#  'Oaktree Drive',
#  'Oaktree Drive',
#  'Oaktree Drive',
#  'Oaktree Drive',
#  'Heatherstone Way',
#  'Franklin Street',
#  'North San Pedro Street',
#  'North San Pedro Street',
#  'North San Pedro Street',
#  'North San Pedro Street',
#  'North San Pedro Street',
#  'North San Pedro Street',
#  'Rankin Avenue',
#  'Rankin Avenue',
#  'Rankin Avenue',
#  'Rankin Avenue',
#  'Rankin Avenue',
#  'Rankin Avenue',
#  'Rankin Avenue',
#  'Rankin Avenue',
#  'West Julian Street',
#  'West Saint John Street',
#  'West Julian',
#  'Mary Avenue',
#  'Crisanto Avenue',
#  'Escuela Avenue',
#  'Escuela Avenue',
#  'Escuela Avenue',
#  'Escuela Avenue',
#  'Montecito Avenue',
#  'Glen Una Avenue',
#  'Glen Una Avenue',
#  'Stevens Creek Boulevard',
#  'Escuela Avenue',
#  'Eunice Avenue',
#  'yes',
#  'yes',
#  'yes',
#  'North Monroe Street',
#  'Garcia Avenue',
#  'Jefferson Drive',
#  'Jefferson Drive',
#  'Leghorn Street',
#  'Willow Street',
#  'Andsbury Avenue',
#  'Cypress Point Drive',
#  'Latham Street',
#  'West El Camino Real',
#  'Sierra Vista Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'Stanford Avenue',
#  'yes',
#  'North Capitol Avenue',
#  'McKee Road',
#  'Moffett Boulevard',
#  'Moffett Boulevard',
#  'Montecito Avenue',
#  'Scott Boulevard',
#  'Bonny Street',
#  'Ortega Avenue',
#  'Dial Way',
#  'Rainbow Drive',
#  'South 10th Street',
#  'California Street',
#  'Hamilton Avenue',
#  'Hamilton Avenue',
#  'Hamilton Avenue',
#  'Hamilton Avenue',
#  'Hamilton Avenue',
#  'Hamilton Avenue',
#  'Willow Road',
#  'Willow Road',
#  'Willow Road',
#  'Willow Road',
#  'Ross Drive',
#  'Ross Drive',
#  'West El Camino Real',
#  'West El Camino Real',
#  'San Tomas Expressway',
#  'Larkin Avenue',
#  'Rainbow Drive',
#  'Prince Drive',
#  'Miller Avenue',
#  'Huntingdon Drive',
#  'Sturgeon Way',
#  'Locust Street',
#  'Forest Avenue',
#  'Montague Expressway',
#  'Montecito Avenue',
#  'Shorebird Way',
#  'San Antonio Road',
#  'Encina Avenue',
#  'Lytton Avenue',
#  'Stockton Avenue',
#  'Leland Avenue',
#  'Leland Avenue',
#  'Adeline Avenue',
#  'Cristo Rey Drive',
#  'Lincoln Avenue',
#  'Fallen Leaf Drive',
#  'San Juan Drive',
#  'Bacchus Drive',
#  'Landess Avenue',
#  'Martin Avenue',
#  'Martin Avenue',
#  'Martin Avenue',
#  'Martin Avenue',
#  'Martin Avenue',
#  'El Camino Real',
#  'North 1st Street',
#  'North 1st Street',
#  'Stanford Avenue',
#  'San Luis Avenue',
#  'Adrian Way',
#  'Hopkins Drive',
#  'Bair Island Road',
#  'Bair Island Road',
#  'Bair Island Road',
#  'True Wind Way',
#  'True Wind Way',
#  'True Wind Way',
#  'Fan Tail Way',
#  'Turnbuckle Drive',
#  'Turnbuckle Drive',
#  'Turnbuckle Drive',
#  'Turnbuckle Drive',
#  'Turnbuckle Drive',
#  'Fan Tail Way',
#  'Turnbuckle Drive',
#  'Turnbuckle Drive',
#  'Turnbuckle Drive',
#  'Bair Island Road',
#  'Bair Island Road',
#  'Sea Anchor Drive',
#  'Sea Anchor Drive',
#  'Sea Anchor Drive',
#  'Sea Anchor Drive',
#  'Sea Anchor Drive',
#  'Uccelli Drive',
#  'Uccelli Drive',
#  'Uccelli Drive',
#  'Uccelli Drive',
#  'Uccelli Drive',
#  'Uccelli Drive',
#  'Uccelli Drive',
#  'Uccelli Drive',
#  'Uccelli Drive',
#  'Blu Harbor Boulevard',
#  'Blu Harbor Boulevard',
#  'Ramona Street',
#  'Sierra Vista Avenue',
#  'Sierra Vista Avenue',
#  'Lone Bluff Way',
#  'Sea Gull Way',
#  'Ted Avenue',
#  'Ted Avenue',
#  'Ted Avenue',
#  'Orchard Parkway',
#  'Orchard Parkway',
#  'Zanker Road',
#  'Bay Road',
#  'Santee Drive',
#  'North De Anza Boulevard',
#  'Lawrence Expressway',
#  'El Camino Real',
#  'Fernald Street',
#  'Sand Hill Road',
#  'Pasteur Drive',
#  'Pasteur Drive',
#  'Hamilton Avenue',
#  'Bryant Street',
#  'North de Anza Boulevard',
#  'East Fremont Avenue',
#  'West Remington Drive',
#  'Rockefeller Drive',
#  'Rockefeller Drive',
#  'West Remington Drive',
#  'Rockefeller Drive',
#  'West Remington Drive',
#  'Rockefeller Drive',
#  'West Remington Drive',
#  'Tilton Drive',
#  'Colorado Place',
#  'Colorado Place',
#  'Colorado Place',
#  'Colorado Avenue',
#  'Colorado Place',
#  'Midtown Court',
#  'Tanland Drive',
#  'Tanland Drive',
#  'El Cajon Way',
#  'University Avenue',
#  'University Avenue',
#  'University Avenue',
#  'East Meadow Drive',
#  'Alma Street',
#  'High Street',
#  'Towle Way',
#  'Cowper Street',
#  'Addison Avenue',
#  'Cowper Street',
#  'Waverley Oaks',
#  'Cowper Street',
#  'Wilkie Way',
#  'Wilkie Way',
#  'Wilkie Way',
#  'Wilkie Way',
#  'Wilkie Way',
#  'Park Boulevard',
#  'Curtner Avenue',
#  'Curtner Avenue',
#  'Curtner Avenue',
#  'Sherman Avenue',
#  'Sheridan Avenue',
#  'Cambridge Avenue',
#  'Hansen Way',
#  'Kendall Avenue',
#  'Page Mill Road',
#  'Manuela Avenue',
#  'El Camino Real',
#  'Hanover Street',
#  'Arastradero Road',
#  'Coyote Hill Road',
#  'Arastradero Road',
#  'Panama Street',
#  'Charter Street',
#  'San Antonio Road',
#  'West Fremont Avenue',
#  'Maraschino Drive',
#  'West Evelyn Avenue',
#  'West Evelyn Avenue',
#  'Escuela Avenue',
#  'Pamela Drive',
#  'West Fremont Avenue',
#  'Country Club Drive',
#  'Alma Street',
#  'California Street',
#  'California Street',
#  'California Street',
#  'California Street',
#  'California Street',
#  'California Street',
#  'Hamilton Avenue',
#  'North 1st Street',
#  'Pasteur Drive',
#  'West Julian Street',
#  'East San Fernando Street',
#  'North Tantau Drive',
#  'South 4th Street',
#  'South Market Street',
#  'North 8th Street',
#  'Mitchell Lane',
#  'Bollinger Road',
#  'Hunter Way',
#  'Chelmsford Drive',
#  'Carver Drive',
#  'Barnhart Avenue',
#  'Shadygrove Drive',
#  'Hyde Avenue',
#  'Brookgrove Lane',
#  'Bollinger Road',
#  'Forge Way',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Via Paviso',
#  'Via Paviso',
#  'Via Paviso',
#  'Via Paviso',
#  'Via Paviso',
#  'Via Paviso',
#  'Via Paviso',
#  'Via Esplendor',
#  'Voss Avenue',
#  'Parlett Place',
#  'Parlett Place',
#  'Miner Place',
#  'Virginia Swan Place',
#  'Ramona Court',
#  'Palo Vista Road',
#  'Ramona Court',
#  'Janice Avenue',
#  'Rancho Ventura Street',
#  'Ramona Court',
#  'Cass Place',
#  'Ramona Court',
#  'Cass Place',
#  'Janice Avenue',
#  'Carta Blanca Street',
#  'Salem Avenue',
#  'Alpine Drive',
#  'Salem Avenue',
#  'Salem Avenue',
#  'Hillcrest Road',
#  'Salem Avenue',
#  'Via Camino Court',
#  'Cupertino Road',
#  'Viceroy Court',
#  'Empire Avenue',
#  'South Stelling Road',
#  'Aster Court',
#  'Aster Lane',
#  'Aster Lane',
#  'South Stelling Road',
#  'South Stelling Road',
#  'Placer Spring Court',
#  'Westshore Court',
#  'Regnart Road',
#  'Rainbow Drive',
#  'Regnart Road',
#  'Conradia Court',
#  'North De Anza Boulevard',
#  'Lomita Avenue',
#  'Regnart Road',
#  'Lindy Lane',
#  'McClellan Road',
#  'Bubb Road',
#  'Stafford Drive',
#  'Stafford Drive',
#  'Rainbow Drive',
#  'Stafford Drive',
#  'Elmsford Drive',
#  'Stafford Drive',
#  'Elmsford Drive',
#  'Stafford Drive',
#  'Yorkshire Drive',
#  'Stafford Drive',
#  'Stafford Drive',
#  'Yorkshire Drive',
#  'Elmsford Drive',
#  'Stafford Drive',
#  'Elmsford Drive',
#  'Yorkshire Drive',
#  'Elmsford Drive',
#  'Stafford Drive',
#  'Stafford Drive',
#  'Elmsford Drive',
#  'Belknap Drive',
#  'Elmsford Drive',
#  'Yorkshire Drive',
#  'Elmsford Drive',
#  'Yorkshire Drive',
#  'Yorkshire Drive',
#  'Bubb Road',
#  'Stafford Drive',
#  'Squirehill Court',
#  'Fallenleaf Lane',
#  'Park Green Lane',
#  'Stevens Creek Boulevard',
#  'Stevens Creek Boulevard',
#  'Denison Avenue',
#  'Cold Harbor Avenue',
#  'Cold Harbor Avenue',
#  'Cold Harbor Avenue',
#  'Vicksburg Court',
#  'Cold Harbor Avenue',
#  'Bette Avenue',
#  'West Estates Drive',
#  'Clifford Drive',
#  'Bette Avenue',
#  'South Blaney Avenue',
#  'Greenwood Court',
#  'Miller Avenue',
#  'Finch Avenue',
#  'Bonny Drive',
#  'North Wolfe Road',
#  'Torre Avenue',
#  'San Pierre Way',
#  'Manuella Road',
#  'West Knickerbocker Drive',
#  'Grant Avenue',
#  'Grant Avenue',
#  'Hansen Way',
#  'Hansen Way',
#  'Belleville Way',
#  'Miranda Avenue',
#  'Latham Street',
#  'Latham Street',
#  'La Donna Avenue',
#  'Timlott Lane',
#  'La Para Avenue',
#  'Maybell Avenue',
#  'Donald Drive',
#  'Arastradero Road',
#  'Los Palos Place',
#  'Donald Drive',
#  'Glenbrook Drive',
#  'Glenbrook Drive',
#  'Pomona Avenue',
#  'Los Palos Avenue',
#  'Pomona Avenue',
#  'Los Palos Place',
#  'Fairmede Avenue',
#  'Pomona Avenue',
#  'Los Palos Avenue',
#  'Fairmede Avenue',
#  'Los Palos Avenue',
#  'Los Palos Avenue',
#  'San Luis Avenue',
#  'Brookdale Avenue',
#  'Arboleda Drive',
#  'El Camino Way',
#  'Plaza Court',
#  'West El Camino Real',
#  'Welch Road',
#  'Welch Road',
#  'Welch Road',
#  'Hedge Road',
#  'San Andreas Court',
#  'North Mathilda Avenue',
#  'North Mathilda Avenue',
#  'East El Camino Real',
#  'Klee Court',
#  'Flamingo Way',
#  'Flamingo Way',
#  'Flicker Way',
#  'Duncardine Way',
#  'Duncardine Way',
#  'San Ramon Court',
#  'San Marcos Circle',
#  'Ormonde Drive',
#  'Vaquero Drive',
#  'North Rengstorff Avenue',
#  'East Bayshore Road',
#  'Lennox Court',
#  'Channing Avenue',
#  'Vallco Parkway',
#  'Cumberland Avenue',
#  'Pear Avenue',
#  'Cumberland Avenue',
#  'Cumberland Avenue',
#  'Cumberland Avenue',
#  'Cumberland Avenue',
#  'Cumberland Avenue',
#  'Cumberland Avenue',
#  'Pear Avenue',
#  'Cumberland Avenue',
#  'Pear Avenue',
#  'Piper Avenue',
#  'Pear Avenue',
#  'Pear Avenue',
#  'Pear Avenue',
#  'Piper Avenue',
#  'Piper Avenue',
#  'Piper Avenue',
#  'Piper Avenue',
#  'Pear Avenue',
#  'Pear Avenue',
#  'Haverhill Drive',
#  'Haverhill Drive',
#  'Harvard Avenue',
#  'Holbrook Place',
#  'Revere Drive',
#  'Revere Drive',
#  'Somerset Drive',
#  'Ticonderoga Drive',
#  'Revere Drive',
#  'Pimento Avenue',
#  'Revere Drive',
#  'Ticonderoga Drive',
#  'Somerset Drive',
#  'Ticonderoga Drive',
#  'South Mary Avenue',
#  'Ticonderoga Drive',
#  'South Mary Avenue',
#  'South Mary Avenue',
#  'Somerset Drive',
#  'Somerset Drive',
#  'Somerset Drive',
#  'Revere Drive',
#  'Pimento Avenue',
#  'Ticonderoga Drive',
#  'West Knickerbocker Drive',
#  'Fairmede Avenue',
#  'Glenbrook Drive',
#  'Quetta Court',
#  'Donald Drive',
#  'Shenandoah Drive',
#  'Ticonderoga Drive',
#  'Somerset Drive',
#  'Ticonderoga Drive',
#  'Pimento Avenue',
#  'Mc Intosh Avenue',
#  'Trenton Drive',
#  'Trenton Drive',
#  'Trenton Drive',
#  'Shenandoah Drive',
#  'Pimento Avenue',
#  'Mc Intosh Avenue',
#  'Trenton Drive',
#  'Shenandoah Drive',
#  'Miller Avenue',
#  'South Mary Avenue',
#  'Ticonderoga Drive',
#  'Mc Intosh Avenue',
#  'Ticonderoga Drive',
#  'Stevens Creek Boulevard',
#  'Brahms Way',
#  'Palmer Avenue',
#  'West California Avenue',
#  'McIntosh Court',
#  'McIntosh Court',
#  'Nelis Court',
#  'South Mary Avenue',
#  'Trenton Drive',
#  'McIntosh Court',
#  'Trenton Drive',
#  'McIntosh Court',
#  'Mc Intosh Avenue',
#  'Navlet Court',
#  'Mc Intosh Avenue',
#  'Trenton Drive',
#  'Trenton Drive',
#  'Trenton Drive',
#  'Trenton Drive',
#  'Mc Intosh Avenue',
#  'Susquehanna Court',
#  'Trenton Drive',
#  'Maraschino Drive',
#  'Nelis Court',
#  'Mc Intosh Avenue',
#  'South Mary Avenue',
#  'Ticonderoga Drive',
#  'Ticonderoga Drive',
#  'Nelis Court',
#  'South Mary Avenue',
#  'Ticonderoga Drive',
#  'Somerset Drive',
#  'Susquehanna Court',
#  'Susquehanna Court',
#  'Trenton Drive',
#  'South Mary Avenue',
#  'Sherwood Court',
#  'Sherwood Court',
#  'West Remington Drive',
#  'Edgewood Drive',
#  'Edgewood Drive',
#  'Edgewood Drive',
#  'Wildwood Lane',
#  'Edgewood Drive',
#  'Edgewood Drive',
#  'Edgewood Drive',
#  'Alberta Avenue',
#  'Thompson Square',
#  'Palmer Avenue',
#  'Bixby Drive',
#  'Cold Harbor Avenue',
#  'Cold Harbor Avenue',
#  'Avocado Place',
#  'Avocado Place',
#  'Mumford Place',
#  'East Bayshore Road',
#  'Edgewood Drive',
#  'Edgewood Drive',
#  'Newell Road',
#  'Price Avenue',
#  'Lupine Avenue',
#  'Middlefield Road',
#  'Middlefield Road',
#  'Torreya Court',
#  'Holly Oak Drive',
#  'Gailen Avenue',
#  'Cork Oak Way',
#  'Holly Oak Drive',
#  'East Meadow Drive',
#  'Richardson Court',
#  'Ross Road',
#  'Middlefield Road',
#  'University Avenue',
#  'Lytton Avenue',
#  'Louis Road',
#  'Olive Avenue',
#  'Louis Road',
#  'Grant Avenue',
#  'Cambridge Avenue',
#  'Cambridge Avenue',
#  'Louis Road',
#  'Greer Road',
#  'Salem Avenue',
#  'Salem Avenue',
#  'Oregon Avenue',
#  'Parkinson Avenue',
#  'Harker Avenue',
#  'Parkinson Avenue',
#  'Richardson Court',
#  'Stockton Place',
#  'Stockton Place',
#  'East Meadow Circle',
#  'Louis Road',
#  'Evergreen Drive',
#  'Evergreen Drive',
#  'Driftwood Drive',
#  'Arbutus Avenue',
#  'Dana Avenue',
#  'El Cajon Way',
#  'Edgewood Drive',
#  'Mumford Place',
#  'Mumford Place',
#  'Dixon Place',
#  'Pacifica Drive',
#  'North De Anza Boulevard',
#  'Page Mill Road',
#  'Santa Clara Street',
#  'Race Street',
#  'Albany Circle',
#  'Albany Circle',
#  'Albany Circle',
#  'Albany Circle',
#  'Albany Circle',
#  'Santa Teresa Street',
#  'Homestead Road',
#  'Homestead Road',
#  'Renaissance Drive',
#  'Los Esteros Road',
#  'Newhall Street',
#  'West Hedding Street',
#  'West Santa Clara Street',
#  'Almaden Boulevard',
#  'West Santa Clara Street',
#  'South Market Street',
#  'Ryland Street',
#  'Matrix Boulevard',
#  'South Market Street',
#  'North 1st Street',
#  'North 1st Street',
#  'North 1st Street',
#  'Lawerence Expressway',
#  'California Street',
#  'California Street',
#  'North Capitol Avenue']

# %% [markdown]
# #### Postcodes Format

# %%
def is_postcode(elem):
    return (elem.attrib['k'] == "addr:postcode")        

def postcode_audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = collections.defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag in ["node","way","relation"]:
            for tag in elem.iter("tag"):
                if is_postcode(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

postcode_audit(DATA)
# Out:
# defaultdict(set,
#             {'94086': {'94086', 'CA 94086'},
#              '94087': {'94087'},
#              '95051': {'95051'},
#              '95112': {'95112'},
#              '94305': {'94305'},
#              '94306': {'94306'},
#              '95050': {'95050'},
#              '94041': {'94041'},
#              '94022': {'94022'},
#              '94043': {'94043'},
#              '94040': {'94040'},
#              '95008': {'95008'},
#              '94024': {'94024', 'CA 94024'},
#              '95070': {'95070'},
#              '95117': {'95117'},
#              '94303': {'94303'},
#              '95125': {'95125'},
#              '95110': {'95110', 'CA 95110'},
#              '95130': {'95130'},
#              '95129': {'95129'},
#              '95014': {'95014', 'CA 95014'},
#              '94025': {'94025'},
#              '94085': {'94085'},
#              '95054': {'95054', 'CA 95054'},
#              '94063': {'94063'},
#              '94301': {'94301'},
#              '95126': {'95126'},
#              '95134': {'95134'},
#              '95014-2029': {'95014-2029'},
#              '94089': {'94089'},
#              '95111': {'95111'},
#              '94539': {'94539'},
#              '95035': {'95035'},
#              '95002': {'95002'},
#              '95014-2405': {'95014-2405'},
#              '94027': {'94027'},
#              '94061': {'94061'},
#              '95128': {'95128'},
#              '94028': {'94028'},
#              '94304': {'94304'},
#              '94036': {'94036'},
#              '95113': {'95113'},
#              '95014-2456': {'95014-2456'},
#              '95132': {'95132'},
#              '95014-2130': {'95014-2130'},
#              '95014-2541': {'95014-2541'},
#              '94538': {'94538'},
#              '95014-2225': {'95014-2225'},
#              '95014-2522': {'95014-2522'},
#              '94401': {'94401'},
#              '95014-2465': {'95014-2465'},
#              '95014-246': {'95014-246'},
#              '95052': {'95052'},
#              '95133': {'95133'},
#              '95014-2105': {'95014-2105'},
#              '95014-1702': {'95014-1702'},
#              '95131': {'95131'},
#              '94086-6406': {'94086-6406'},
#              '95122': {'95122'},
#              '95121': {'95121'},
#              '95110-2007': {'95110-2007'},
#              '95014-0451': {'95014-0451'},
#              '95014-3833': {'95014-3833'},
#              '95014-3556': {'95014-3556'},
#              '95014-3660': {'95014-3660'},
#              '95014-3508': {'95014-3508'},
#              '95014-3554': {'95014-3554'},
#              '95014-3560': {'95014-3560'},
#              '95014-6413': {'95014-6413'},
#              '95014-3618': {'95014-3618'},
#              '95014-3510': {'95014-3510'},
#              '95014-3512': {'95014-3512'},
#              '95014-4635': {'95014-4635'},
#              '95014-4641': {'95014-4641'},
#              '95014-5408': {'95014-5408'},
#              '95014-5451': {'95014-5451'},
#              '95014-5418': {'95014-5418'},
#              '95014-5456': {'95014-5456'},
#              '95014-5424': {'95014-5424'},
#              '95014-5457': {'95014-5457'},
#              '95014-5426': {'95014-5426'},
#              '95014-5402': {'95014-5402'},
#              '95014-5427': {'95014-5427'},
#              '95014-5429': {'95014-5429'},
#              '95014-5413': {'95014-5413'},
#              '95014-543': {'95014-543'},
#              '95014-5404': {'95014-5404'},
#              '95014-5420': {'95014-5420'},
#              '95014-5442': {'95014-5442'},
#              '95014-2054': {'95014-2054'},
#              '95014-0120': {'95014-0120'},
#              '95014-0141': {'95014-0141'},
#              '95014-0114': {'95014-0114'},
#              '95014-0137': {'95014-0137'},
#              '95014-0116': {'95014-0116'},
#              '95014-0337': {'95014-0337'},
#              '95014-0494': {'95014-0494'},
#              '95014-0455': {'95014-0455'},
#              '95014-0444': {'95014-0444'},
#              '95014-0456': {'95014-0456'},
#              '95014-0492': {'95014-0492'},
#              '95014-0445': {'95014-0445'},
#              '95014-0440': {'95014-0440'},
#              '95014-0447': {'95014-0447'},
#              '95014-0433': {'95014-0433'},
#              '95014-0434': {'95014-0434'},
#              '95014-0493': {'95014-0493'},
#              '95014-0437': {'95014-0437'},
#              '95014-0453': {'95014-0453'},
#              '95014-0446': {'95014-0446'},
#              '95014-0496': {'95014-0496'},
#              '95014-0438': {'95014-0438'},
#              '95014-0457': {'95014-0457'},
#              '95014-0497': {'95014-0497'},
#              '95014-0454': {'95014-0454'},
#              '95014-0499': {'95014-0499'},
#              '95014-6302': {'95014-6302'},
#              '95014-0448': {'95014-0448'},
#              '95014-0495': {'95014-0495'},
#              '95014-0449': {'95014-0449'},
#              '95014-0400': {'95014-0400'},
#              '95014-0431': {'95014-0431'},
#              '95014-6344': {'95014-6344'},
#              '95014-6348': {'95014-6348'},
#              '95014-0436': {'95014-0436'},
#              '95014-030': {'95014-030'},
#              '95014-0358': {'95014-0358'},
#              '95014-2540': {'95014-2540'},
#              '95014-2582': {'95014-2582'},
#              '95014-2557': {'95014-2557'},
#              '95014-0516': {'95014-0516'},
#              '95014-0523': {'95014-0523'},
#              '95014-0521': {'95014-0521'},
#              '95014-0557': {'95014-0557'},
#              '95014-0513': {'95014-0513'},
#              '95014-0542': {'95014-0542'},
#              '95014-0541': {'95014-0541'},
#              '95014-0526': {'95014-0526'},
#              '95014-0525': {'95014-0525'},
#              '95014-0563': {'95014-0563'},
#              '95014-0534': {'95014-0534'},
#              '95014-0522': {'95014-0522'},
#              '95014-0544': {'95014-0544'},
#              '95014-0528': {'95014-0528'},
#              '95014-0514': {'95014-0514'},
#              '95014-0537': {'95014-0537'},
#              '95014-0527': {'95014-0527'},
#              '95014-0543': {'95014-0543'},
#              '95014-0536': {'95014-0536'},
#              '95014-0533': {'95014-0533'},
#              '95014-0599': {'95014-0599'},
#              '95014-0515': {'95014-0515'},
#              '95014-0539': {'95014-0539'},
#              '95014-0538': {'95014-0538'},
#              '95014-0530': {'95014-0530'},
#              '95014-0529': {'95014-0529'},
#              '95014-0564': {'95014-0564'},
#              '95014-0532': {'95014-0532'},
#              '95014-6314': {'95014-6314'},
#              '95014-0531': {'95014-0531'},
#              '95014-0540': {'95014-0540'},
#              '95014-0535': {'95014-0535'},
#              '95014-0565': {'95014-0565'},
#              '95014-6319': {'95014-6319'},
#              '95014-0560': {'95014-0560'},
#              '95014-0556': {'95014-0556'},
#              '95014-0510': {'95014-0510'},
#              '95014-0550': {'95014-0550'},
#              '95014-0549': {'95014-0549'},
#              '95014-0553': {'95014-0553'},
#              '95014-0512': {'95014-0512'},
#              '95014-0509': {'95014-0509'},
#              '95014-0552': {'95014-0552'},
#              '95014-0554': {'95014-0554'},
#              '95014-0568': {'95014-0568'},
#              '95014-0551': {'95014-0551'},
#              '95014-0511': {'95014-0511'},
#              '95014-0506': {'95014-0506'},
#              '95014-0518': {'95014-0518'},
#              '95014-0567': {'95014-0567'},
#              '95014-0502': {'95014-0502'},
#              '95014-0501': {'95014-0501'},
#              '95014-0546': {'95014-0546'},
#              '95014-0545': {'95014-0545'},
#              '95014-0505': {'95014-0505'},
#              '95014-0517': {'95014-0517'},
#              '95014-0548': {'95014-0548'},
#              '95014-0508': {'95014-0508'},
#              '95014-0520': {'95014-0520'},
#              '95014-0504': {'95014-0504'},
#              '95014-0547': {'95014-0547'},
#              '95014-0503': {'95014-0503'},
#              '95014-0562': {'95014-0562'},
#              '95014-0507': {'95014-0507'},
#              '95014-0519': {'95014-0519'},
#              '95014-0566': {'95014-0566'},
#              '95014-6316': {'95014-6316'},
#              '95014-6315': {'95014-6315'},
#              '95014-6318': {'95014-6318'},
#              '95014-6317': {'95014-6317'},
#              '95014-2640': {'95014-2640'},
#              '95014-2644': {'95014-2644'},
#              '95014-2643': {'95014-2643'},
#              '95014-2685': {'95014-2685'},
#              '95014-2658': {'95014-2658'},
#              '95014-2642': {'95014-2642'},
#              '95014-2659': {'95014-2659'},
#              '95014-2641': {'95014-2641'},
#              '95014-2654': {'95014-2654'},
#              '95014-5613': {'95014-5613'},
#              '95014-5624': {'95014-5624'},
#              '95014-5623': {'95014-5623'},
#              '95014-5658': {'95014-5658'},
#              '95014-5608': {'95014-5608'},
#              '95014-5607': {'95014-5607'},
#              '95014-5615': {'95014-5615'},
#              '95014-5606': {'95014-5606'},
#              '95014-5605': {'95014-5605'},
#              '95014-5611': {'95014-5611'},
#              '95014-5631': {'95014-5631'},
#              '95014-5609': {'95014-5609'},
#              '95014-6581': {'95014-6581'},
#              '95014-6566': {'95014-6566'},
#              '95014-6565': {'95014-6565'},
#              '95014-6568': {'95014-6568'},
#              '95014-6578': {'95014-6578'},
#              '95014-6579': {'95014-6579'},
#              '95014-6562': {'95014-6562'},
#              '95014-6570': {'95014-6570'},
#              '95014-6573': {'95014-6573'},
#              '95014-5620': {'95014-5620'},
#              '95014-5621': {'95014-5621'},
#              '95014-5610': {'95014-5610'},
#              '95014-5617': {'95014-5617'},
#              '95014-5622': {'95014-5622'},
#              '95014-5616': {'95014-5616'},
#              '95014-5618': {'95014-5618'},
#              '95014-5633': {'95014-5633'},
#              '95014-5632': {'95014-5632'},
#              '95014-5619': {'95014-5619'},
#              '95014-5634': {'95014-5634'},
#              '95014-5612': {'95014-5612'},
#              '95014-5635': {'95014-5635'},
#              '95014-5614': {'95014-5614'},
#              '95014-5654': {'95014-5654'},
#              '95014-5628': {'95014-5628'},
#              '95014-5638': {'95014-5638'},
#              '95014-5651': {'95014-5651'},
#              '95014-5639': {'95014-5639'},
#              '95014-5643': {'95014-5643'},
#              '95014-5644': {'95014-5644'},
#              '95014-5642': {'95014-5642'},
#              '95014-5640': {'95014-5640'},
#              '95014-5641': {'95014-5641'},
#              '95014-6546': {'95014-6546'},
#              '95014-6542': {'95014-6542'},
#              '95014-6550': {'95014-6550'},
#              '95014-6554': {'95014-6554'},
#              '95014-6540': {'95014-6540'},
#              '95014-6539': {'95014-6539'},
#              '95014-2655': {'95014-2655'},
#              '95014-2662': {'95014-2662'},
#              '95014-2633': {'95014-2633'},
#              '95014-2632': {'95014-2632'},
#              '95014-2600': {'95014-2600'},
#              '95014-2667': {'95014-2667'},
#              '95014-2609': {'95014-2609'},
#              '95014-2617': {'95014-2617'},
#              '95014-2618': {'95014-2618'},
#              '95014-2649': {'95014-2649'},
#              '95014-2650': {'95014-2650'},
#              '95014-2653': {'95014-2653'},
#              '95014-2635': {'95014-2635'},
#              '95014-2651': {'95014-2651'},
#              '95014-2681': {'95014-2681'},
#              '95014-2637': {'95014-2637'},
#              '95014-2682': {'95014-2682'},
#              '95014-2652': {'95014-2652'},
#              '95014-2657': {'95014-2657'},
#              '95014-2639': {'95014-2639'},
#              '95014-2636': {'95014-2636'},
#              '95014-2680': {'95014-2680'},
#              '95014-2638': {'95014-2638'},
#              '95014-3913': {'95014-3913'},
#              '95014-3922': {'95014-3922'},
#              '95014-3938': {'95014-3938'},
#              '95014-3975': {'95014-3975'},
#              '95014-3924': {'95014-3924'},
#              '95014-3963': {'95014-3963'},
#              '95014-3911': {'95014-3911'},
#              '95014-3937': {'95014-3937'},
#              '95014-3941': {'95014-3941'},
#              '95014-3900': {'95014-3900'},
#              '95014-3902': {'95014-3902'},
#              '95014-3932': {'95014-3932'},
#              '95014-3904': {'95014-3904'},
#              '95014-3903': {'95014-3903'},
#              '95014-3934': {'95014-3934'},
#              '95014-3920': {'95014-3920'},
#              '95014-232': {'95014-232'},
#              '95014-2344': {'95014-2344'},
#              '95014-2301': {'95014-2301'},
#              '95014-2343': {'95014-2343'},
#              '95014-2223': {'95014-2223'},
#              '95014-2346': {'95014-2346'},
#              '95014-2219': {'95014-2219'},
#              '95014-2238': {'95014-2238'},
#              '95014-2224': {'95014-2224'},
#              '95014-2348': {'95014-2348'},
#              '95014-2307': {'95014-2307'},
#              '95014-2007': {'95014-2007'},
#              '95014-2342': {'95014-2342'},
#              '95014-2341': {'95014-2341'},
#              '95014-2235': {'95014-2235'},
#              '95014-2222': {'95014-2222'},
#              '95014-2258': {'95014-2258'},
#              '95014-2257': {'95014-2257'},
#              '95014-2260': {'95014-2260'},
#              '95014-3945': {'95014-3945'},
#              '95014-3969': {'95014-3969'},
#              '95014-3965': {'95014-3965'},
#              '95014-3908': {'95014-3908'},
#              '95014-3916': {'95014-3916'},
#              '95014-3917': {'95014-3917'},
#              '95014-3909': {'95014-3909'},
#              '95014-5405': {'95014-5405'},
#              '95014-5400': {'95014-5400'},
#              '95014-5403': {'95014-5403'},
#              '95014-542': {'95014-542'},
#              '95014-3927': {'95014-3927'},
#              '95014-3928': {'95014-3928'},
#              '95014-3929': {'95014-3929'},
#              '95014-2771': {'95014-2771'},
#              '95014-2753': {'95014-2753'},
#              '95014-3968': {'95014-3968'},
#              '95014-3960': {'95014-3960'},
#              '95014-5411': {'95014-5411'},
#              '95014-2750': {'95014-2750'},
#              '95014-2760': {'95014-2760'},
#              '95014-2762': {'95014-2762'},
#              '95014-2701': {'95014-2701'},
#              '95014-3931': {'95014-3931'},
#              '95014-1047': {'95014-1047'},
#              '95014-2746': {'95014-2746'},
#              '95014-2733': {'95014-2733'},
#              '95014-2739': {'95014-2739'},
#              '95014-2742': {'95014-2742'},
#              '95014-2731': {'95014-2731'},
#              '95014-2767': {'95014-2767'},
#              '95014-2769': {'95014-2769'},
#              '95014-2603': {'95014-2603'},
#              '95014-0803': {'95014-0803'},
#              '95014-1070': {'95014-1070'},
#              '95014-1212': {'95014-1212'},
#              '95014-1238': {'95014-1238'},
#              '95014-1215': {'95014-1215'},
#              '95014-1214': {'95014-1214'},
#              '95014-1210': {'95014-1210'},
#              '95014-1204': {'95014-1204'},
#              '95014-1205': {'95014-1205'},
#              '95014-1216': {'95014-1216'},
#              '95014-1203': {'95014-1203'},
#              '95014-1217': {'95014-1217'},
#              '95014-1211': {'95014-1211'},
#              '95014-1153': {'95014-1153'},
#              '95014-1219': {'95014-1219'},
#              '95014-1247': {'95014-1247'},
#              '95014-1133': {'95014-1133'},
#              '95014-1206': {'95014-1206'},
#              '95014-1254': {'95014-1254'},
#              '95014-1169': {'95014-1169'},
#              '95014-1119': {'95014-1119'},
#              '95014-1132': {'95014-1132'},
#              '95014-1660': {'95014-1660'},
#              '95014-1601': {'95014-1601'},
#              '95014-1607': {'95014-1607'},
#              '95014-1614': {'95014-1614'},
#              '95014-1627': {'95014-1627'},
#              '95014-1615': {'95014-1615'},
#              '95014-1631': {'95014-1631'},
#              '95014-1617': {'95014-1617'},
#              '95014-1618': {'95014-1618'},
#              '95014-1625': {'95014-1625'},
#              '95014-1620': {'95014-1620'},
#              '95014-1619': {'95014-1619'},
#              '95014-1659': {'95014-1659'},
#              '95014-5363': {'95014-5363'},
#              '95014-5237': {'95014-5237'},
#              '95014-5251': {'95014-5251'},
#              '95014-5158': {'95014-5158'},
#              '95014-515': {'95014-515'},
#              '95014-4814': {'95014-4814'},
#              '95014-5106': {'95014-5106'},
#              '95014-4822': {'95014-4822'},
#              '95014-4827': {'95014-4827'},
#              '95014-4811': {'95014-4811'},
#              '95014-4841': {'95014-4841'},
#              '95014-4851': {'95014-4851'},
#              '95014-2124': {'95014-2124'},
#              '95014-1942': {'95014-1942'},
#              '95014-1941': {'95014-1941'},
#              '95014-1940': {'95014-1940'},
#              '95014-1939': {'95014-1939'},
#              '95014-1938': {'95014-1938'},
#              '95014-1937': {'95014-1937'},
#              '95014-1812': {'95014-1812'},
#              '95014-1644': {'95014-1644'},
#              '95014-1875': {'95014-1875'},
#              '95014-2123': {'95014-2123'},
#              '95014-1735': {'95014-1735'},
#              '95014-2107': {'95014-2107'},
#              '95014-1804': {'95014-1804'},
#              '95014-1803': {'95014-1803'},
#              '95014-1825': {'95014-1825'},
#              '95014-1802': {'95014-1802'},
#              '95014-1818': {'95014-1818'},
#              '95014-1799': {'95014-1799'},
#              '95014-1806': {'95014-1806'},
#              '95014-1826': {'95014-1826'},
#              '95014-1829': {'95014-1829'},
#              '95014-2102': {'95014-2102'},
#              '95014-1930': {'95014-1930'},
#              '95014-1953': {'95014-1953'},
#              '95014-1952': {'95014-1952'},
#              '95014-1968': {'95014-1968'},
#              '95014-1931': {'95014-1931'},
#              '95014-1954': {'95014-1954'},
#              '95014-1944': {'95014-1944'},
#              '95014-1951': {'95014-1951'},
#              '95014-1967': {'95014-1967'},
#              '95014-1932': {'95014-1932'},
#              '95014-1955': {'95014-1955'},
#              '95014-1945': {'95014-1945'},
#              '95014-1950': {'95014-1950'},
#              '95014-1966': {'95014-1966'},
#              '95014-1933': {'95014-1933'},
#              '95014-1956': {'95014-1956'},
#              '95014-1946': {'95014-1946'},
#              '95014-1949': {'95014-1949'},
#              '95014-1965': {'95014-1965'},
#              '95014-1957': {'95014-1957'},
#              '95014-1964': {'95014-1964'},
#              '95014-1958': {'95014-1958'},
#              '95014-1963': {'95014-1963'},
#              '95014-1934': {'95014-1934'},
#              '95014-1935': {'95014-1935'},
#              '95014-1912': {'95014-1912'},
#              '95014-1754': {'95014-1754'},
#              '95014-6201': {'95014-6201'},
#              '95014-1701': {'95014-1701'},
#              '95014-2220': {'95014-2220'},
#              '95014-1959': {'95014-1959'},
#              '95014-1960': {'95014-1960'},
#              '95014-1961': {'95014-1961'},
#              '95014-1962': {'95014-1962'},
#              '95014-1703': {'95014-1703'},
#              '95014-1902': {'95014-1902'},
#              '95014-2848': {'95014-2848'},
#              '95014-2806': {'95014-2806'},
#              '95014-2857': {'95014-2857'},
#              '95014-2812': {'95014-2812'},
#              '95014-2829': {'95014-2829'},
#              '95014-2819': {'95014-2819'},
#              '95014-4056': {'95014-4056'},
#              '95014-1156': {'95014-1156'},
#              '95014-2858': {'95014-2858'},
#              '95014-2844': {'95014-2844'},
#              '95014-4025': {'95014-4025'},
#              '95014-4751': {'95014-4751'},
#              '95014-4007': {'95014-4007'},
#              '95014-4006': {'95014-4006'},
#              '95014-4005': {'95014-4005'},
#              '95014-4033': {'95014-4033'},
#              '95014-4706': {'95014-4706'},
#              '95014-4715': {'95014-4715'},
#              '95014-4709': {'95014-4709'},
#              '95014-5905': {'95014-5905'},
#              '95014-2816': {'95014-2816'},
#              '95014-4132': {'95014-4132'},
#              '95014-5904': {'95014-5904'},
#              '95014-5945': {'95014-5945'},
#              '95014-5917': {'95014-5917'},
#              '95014-5907': {'95014-5907'},
#              '95014-5955': {'95014-5955'},
#              '95014-5919': {'95014-5919'},
#              '95014-4133': {'95014-4133'},
#              '95014-5920': {'95014-5920'},
#              '95014-4167': {'95014-4167'},
#              '95014-4166': {'95014-4166'},
#              '95014-4149': {'95014-4149'},
#              '95014-4150': {'95014-4150'},
#              '95014-5924': {'95014-5924'},
#              '95014-1120': {'95014-1120'},
#              '95014-1149': {'95014-1149'},
#              '95014-5935': {'95014-5935'},
#              '95014-5936': {'95014-5936'},
#              '95014-5937': {'95014-5937'},
#              '95014-5938': {'95014-5938'},
#              '95014-5910': {'95014-5910'},
#              '95014-5913': {'95014-5913'},
#              '95014-5926': {'95014-5926'},
#              '95014-5951': {'95014-5951'},
#              '95014-5902': {'95014-5902'},
#              '95014-5914': {'95014-5914'},
#              '95014-4003': {'95014-4003'},
#              '95014-4008': {'95014-4008'},
#              '95014-4051': {'95014-4051'},
#              '95014-4065': {'95014-4065'},
#              '95014-4042': {'95014-4042'},
#              '95014-4064': {'95014-4064'},
#              '95014-4050': {'95014-4050'},
#              '95014-4004': {'95014-4004'},
#              '95014-4043': {'95014-4043'},
#              '95014-4044': {'95014-4044'},
#              '95014-4045': {'95014-4045'},
#              '95014-4046': {'95014-4046'},
#              '95014-4048': {'95014-4048'},
#              '95014-4047': {'95014-4047'},
#              '95014-4049': {'95014-4049'},
#              '95014-4001': {'95014-4001'},
#              '95014-4009': {'95014-4009'},
#              '95014-4172': {'95014-4172'},
#              '95014-4173': {'95014-4173'},
#              '95014-4102': {'95014-4102'},
#              '95014-4103': {'95014-4103'},
#              '95014-4175': {'95014-4175'},
#              '95014-4135': {'95014-4135'},
#              '95014-4139': {'95014-4139'},
#              '95014-4136': {'95014-4136'},
#              '95014-4138': {'95014-4138'},
#              '95014-4137': {'95014-4137'},
#              '95014-4104': {'95014-4104'},
#              '95014-4176': {'95014-4176'},
#              '95014-4140': {'95014-4140'},
#              '95014-4105': {'95014-4105'},
#              '95014-4177': {'95014-4177'},
#              '95014-4106': {'95014-4106'},
#              '95014-4178': {'95014-4178'},
#              '95014-4179': {'95014-4179'},
#              '95014-4107': {'95014-4107'},
#              '95014-4180': {'95014-4180'},
#              '95014-4109': {'95014-4109'},
#              '95014-4181': {'95014-4181'},
#              '95014-4182': {'95014-4182'},
#              '95014-4110': {'95014-4110'},
#              '95014-4148': {'95014-4148'},
#              '95014-4963': {'95014-4963'},
#              '95014-5209': {'95014-5209'},
#              '95014-5023': {'95014-5023'},
#              '95014-5067': {'95014-5067'},
#              '95014-5073': {'95014-5073'},
#              '95014-5026': {'95014-5026'},
#              '95014-5036': {'95014-5036'},
#              '95014-5027': {'95014-5027'},
#              'CUPERTINO': {'CUPERTINO'},
#              '95014-5081': {'95014-5081'},
#              '95014-5082': {'95014-5082'},
#              '95014-5083': {'95014-5083'},
#              '95014-5084': {'95014-5084'},
#              '95014-5085': {'95014-5085'},
#              '95014-5086': {'95014-5086'},
#              '95014-5087': {'95014-5087'},
#              '95014-5088': {'95014-5088'},
#              '95014-5066': {'95014-5066'},
#              '95014-5056': {'95014-5056'},
#              '95014-5065': {'95014-5065'},
#              '95014-5343': {'95014-5343'},
#              '95014-5310': {'95014-5310'},
#              '95014-4246': {'95014-4246'},
#              '95014-4247': {'95014-4247'},
#              '95014-4248': {'95014-4248'},
#              '95014-4241': {'95014-4241'},
#              '95014-4242': {'95014-4242'},
#              '95014-4243': {'95014-4243'},
#              '95014-4244': {'95014-4244'},
#              '95014-4245': {'95014-4245'},
#              '95014-4249': {'95014-4249'},
#              '95014-4260': {'95014-4260'},
#              '95014-4240': {'95014-4240'},
#              '95014-4259': {'95014-4259'},
#              '95014-4239': {'95014-4239'},
#              '95014-4250': {'95014-4250'},
#              '95014-4258': {'95014-4258'},
#              '95014-4238': {'95014-4238'},
#              '95014-4251': {'95014-4251'},
#              '95014-4257': {'95014-4257'},
#              '95014-4267': {'95014-4267'},
#              '95014-4230': {'95014-4230'},
#              '95014-4256': {'95014-4256'},
#              '95014-4237': {'95014-4237'},
#              '95014-4252': {'95014-4252'},
#              '95014-4268': {'95014-4268'},
#              '95014-4236': {'95014-4236'},
#              '95014-4231': {'95014-4231'},
#              '95014-4255': {'95014-4255'},
#              '95014-4228': {'95014-4228'},
#              '95014-4235': {'95014-4235'},
#              '95014-4232': {'95014-4232'},
#              '95014-4253': {'95014-4253'},
#              '95014-4233': {'95014-4233'},
#              '95014-4234': {'95014-4234'},
#              '95014-4201': {'95014-4201'},
#              '95014-4254': {'95014-4254'},
#              '95014-4221': {'95014-4221'},
#              '95014-4218': {'95014-4218'},
#              '95014-4431': {'95014-4431'},
#              '95014-4224': {'95014-4224'},
#              '95014-3004': {'95014-3004'},
#              '95014-4304': {'95014-4304'},
#              '95014-2958': {'95014-2958'},
#              '95014-5702': {'95014-5702'},
#              '95014-2128': {'95014-2128'},
#              '95014-2140': {'95014-2140'},
#              '95014-2141': {'95014-2141'},
#              '95014-2142': {'95014-2142'},
#              '95014-2143': {'95014-2143'},
#              '95014-2144': {'95014-2144'},
#              '95014-2143;95014-2144': {'95014-2143;95014-2144'},
#              '95014-2146': {'95014-2146'},
#              '95014-2147': {'95014-2147'},
#              '95014-2145': {'95014-2145'},
#              '95014-2148': {'95014-2148'},
#              '95014-3114': {'95014-3114'},
#              '95014-3125': {'95014-3125'},
#              '95014-2134': {'95014-2134'},
#              '95014-2133': {'95014-2133'},
#              '95014-2135': {'95014-2135'},
#              '95014-2137': {'95014-2137'},
#              '95014-2136': {'95014-2136'},
#              '95014-2138': {'95014-2138'},
#              '95014-2139': {'95014-2139'},
#              '95014-321': {'95014-321'},
#              '95014-2265': {'95014-2265'},
#              '95014-2280': {'95014-2280'},
#              '95014-3002': {'95014-3002'},
#              '95014-4450': {'95014-4450'},
#              '95014-445': {'95014-445'},
#              '95014-4500': {'95014-4500'},
#              '95014-4566': {'95014-4566'},
#              '95014-4532': {'95014-4532'},
#              '95014-4440': {'95014-4440'},
#              '95014-4436': {'95014-4436'},
#              '95014-4439': {'95014-4439'},
#              '95014-6039': {'95014-6039'},
#              '95014-6007': {'95014-6007'},
#              '95014-2403': {'95014-2403'},
#              '95014-2451': {'95014-2451'},
#              '95014-2450': {'95014-2450'},
#              '95014-2453': {'95014-2453'},
#              '95014-2452': {'95014-2452'},
#              '95014-2322': {'95014-2322'},
#              '95014-2305': {'95014-2305'},
#              '95014-2366': {'95014-2366'},
#              '95014-3340': {'95014-3340'},
#              '95014-3421': {'95014-3421'},
#              '95014-3423': {'95014-3423'},
#              '95014-3319': {'95014-3319'},
#              '95014-3465': {'95014-3465'},
#              '95014-3361': {'95014-3361'},
#              '95014-3320': {'95014-3320'},
#              '95014-3316': {'95014-3316'},
#              '95014-2415': {'95014-2415'},
#              '95014-3363': {'95014-3363'},
#              '95014-3367': {'95014-3367'},
#              '95014-3370': {'95014-3370'},
#              '95014-3371': {'95014-3371'},
#              '95014-3364': {'95014-3364'},
#              '95014-3369': {'95014-3369'},
#              '95014-3366': {'95014-3366'},
#              '95014-3362': {'95014-3362'},
#              '95014-3365': {'95014-3365'},
#              '95014-4506': {'95014-4506'},
#              '95014-4525': {'95014-4525'},
#              '95014-4631': {'95014-4631'},
#              '95014-4632': {'95014-4632'},
#              '95014-4642': {'95014-4642'},
#              '95014-4661': {'95014-4661'},
#              '95014-3400': {'95014-3400'},
#              '95014-3549': {'95014-3549'},
#              '95014-2558': {'95014-2558'},
#              '95014-3454': {'95014-3454'},
#              '95014-2526': {'95014-2526'},
#              '95014-3642': {'95014-3642'},
#              '95014-3806': {'95014-3806'},
#              '95014-3542': {'95014-3542'},
#              '95014-3689': {'95014-3689'},
#              '95014-3630': {'95014-3630'},
#              '95014-3643': {'95014-3643'},
#              '95014-3631': {'95014-3631'},
#              '95014-3870': {'95014-3870'},
#              '95014-3638': {'95014-3638'},
#              '95014-366': {'95014-366'},
#              '95014-3668': {'95014-3668'},
#              '95014-3524': {'95014-3524'},
#              '95014-3544': {'95014-3544'},
#              '95014-3702': {'95014-3702'},
#              '95014-3822': {'95014-3822'},
#              '95014-3858': {'95014-3858'},
#              '95014-3803': {'95014-3803'},
#              '95014-3859': {'95014-3859'},
#              '95014-3601': {'95014-3601'},
#              '95014-2502': {'95014-2502'},
#              '95014-3553': {'95014-3553'},
#              '95014-3552': {'95014-3552'},
#              '95014-3799': {'95014-3799'},
#              '95014-7601': {'95014-7601'},
#              '95014-7604': {'95014-7604'},
#              '95014-763': {'95014-763'},
#              '95014-7607': {'95014-7607'},
#              '95014-7610': {'95014-7610'},
#              '95014-7616': {'95014-7616'},
#              '95014-7624': {'95014-7624'},
#              '95014-7627': {'95014-7627'},
#              '95014-4271': {'95014-4271'},
#              '95014-4205': {'95014-4205'},
#              '95014-4204': {'95014-4204'},
#              '95014-2126': {'95014-2126'},
#              '95014-3007': {'95014-3007'},
#              '95014-3026': {'95014-3026'},
#              '95014-4226': {'95014-4226'},
#              '95014-2930': {'95014-2930'},
#              '95014-3011': {'95014-3011'},
#              '95014-2942': {'95014-2942'},
#              '95014-2960': {'95014-2960'},
#              '95014-2920': {'95014-2920'},
#              '95014-2921': {'95014-2921'},
#              '95014-2120': {'95014-2120'},
#              '95014-2193': {'95014-2193'},
#              '95014-2976': {'95014-2976'},
#              '95014-2917': {'95014-2917'},
#              '95014-0708': {'95014-0708'},
#              '95014-0739': {'95014-0739'},
#              '95014-0615': {'95014-0615'},
#              '95014-0614': {'95014-0614'},
#              '95014-0605': {'95014-0605'},
#              '95014-0616': {'95014-0616'},
#              '95014-0617': {'95014-0617'},
#              '95014-061': {'95014-061'},
#              '95014-0619': {'95014-0619'},
#              '95014-0721': {'95014-0721'},
#              '95014-0706': {'95014-0706'},
#              '951251': {'951251'},
#              '95127': {'95127'},
#              '95116': {'95116', 'CA 95116'},
#              '94035': {'CA 94035'},
#              '95014-2036': {'95014-2036'},
#              '94088-3453': {'94088-3453'},
#              '95014-1763': {'95014-1763'},
#              '95014-1704': {'95014-1704'},
#              '95014-2028': {'95014-2028'},
#              '95014-1972': {'95014-1972'},
#              '95014-2171': {'95014-2171'},
#              '95014-4165': {'95014-4165'},
#              '95191': {'95191'},
#              '95148': {'95148'},
#              '95014-4449': {'95014-4449'},
#              '95014-4447': {'95014-4447'},
#              '95014-3009': {'95014-3009'},
#              '95014-3023': {'95014-3023'},
#              '95014-2131': {'95014-2131'},
#              '95014-3029': {'95014-3029'},
#              '95014-2268': {'95014-2268'},
#              '95014-2210': {'95014-2210'},
#              '94035-0016': {'94035-0016'},
#              '95136': {'95136'},
#              '95014-3202': {'95014-3202'},
#              '94088-3707': {'94088-3707'},
#              '95014-0353': {'95014-0353'},
#              '95014-4171': {'95014-4171'},
#              '95014-1218': {'95014-1218'},
#              '94084': {'94084'},
#              '95014-3541': {'95014-3541'},
#              '95014-2306': {'95014-2306'},
#              '95014-2308': {'95014-2308'},
#              '95014-2398': {'95014-2398'},
#              '95014-2321': {'95014-2321'},
#              '95014-2422': {'95014-2422'},
#              '95014-2356': {'95014-2356'},
#              '95014-2380': {'95014-2380'},
#              '95014-2505': {'95014-2505'},
#              '95014-2404': {'95014-2404'},
#              '95014-2504': {'95014-2504'},
#              '95014-3674': {'95014-3674'},
#              '95014-3662': {'95014-3662'},
#              '95014-3027': {'95014-3027'},
#              '95014-2149': {'95014-2149'},
#              '95014-3028': {'95014-3028'},
#              '95014-2121': {'95014-2121'},
#              '95014-2106': {'95014-2106'},
#              '95014-2170': {'95014-2170'},
#              '95014-2101': {'95014-2101'},
#              '95014-2122': {'95014-2122'},
#              '95014-2263': {'95014-2263'},
#              '95014-2262': {'95014-2262'},
#              '95014-1899': {'95014-1899'},
#              '95014-5799': {'95014-5799'},
#              '95014-2211': {'95014-2211'},
#              '95014-2251': {'95014-2251'},
#              '95014-3203': {'95014-3203'},
#              '95014-218': {'95014-218'},
#              '95014-3010': {'95014-3010'},
#              '95014-3000': {'95014-3000'},
#              '95014-3003': {'95014-3003'},
#              '95014-3008': {'95014-3008'},
#              '95014-3012': {'95014-3012'},
#              '95014-3018': {'95014-3018'},
#              '95014-5724': {'95014-5724'},
#              '95014-5731': {'95014-5731'},
#              '95014-5715': {'95014-5715'},
#              '95014-5728': {'95014-5728'},
#              '95014-5719': {'95014-5719'},
#              '94089-2701': {'94089-2701'},
#              '515': {'515'},
#              '95014-2027': {'95014-2027'},
#              '95014-2030': {'95014-2030'},
#              '95014-570': {'95014-570'},
#              '95014-1560': {'95014-1560'},
#              '95014-5713': {'95014-5713'},
#              '94025-1246': {'94025-1246'},
#              '95014-1506': {'95014-1506'},
#              '95014-1549': {'95014-1549'},
#              '95014-1541': {'95014-1541'},
#              '95014-1406': {'95014-1406'},
#              '95014-1534': {'95014-1534'},
#              '95014-1551': {'95014-1551'},
#              '95014-1528': {'95014-1528'},
#              '95014-1547': {'95014-1547'},
#              '95014-1530': {'95014-1530'},
#              '95014-1562': {'95014-1562'},
#              '95014-1526': {'95014-1526'},
#              '95014-1469': {'95014-1469'},
#              '95014-1408': {'95014-1408'},
#              '95014-1558': {'95014-1558'},
#              '95014-1569': {'95014-1569'},
#              '95014-1532': {'95014-1532'},
#              '95014-1479': {'95014-1479'},
#              '95014-1467': {'95014-1467'},
#              '95014-1538': {'95014-1538'},
#              '95014-1543': {'95014-1543'},
#              '95014-1539': {'95014-1539'},
#              '94301-2019': {'94301-2019'},
#              '95014-0607': {'95014-0607'},
#              '95014-0439': {'95014-0439'},
#              '95014-2031': {'95014-2031'},
#              '95014-2098': {'95014-2098'},
#              '94304-1050': {'94304-1050'},
#              '95014-0555': {'95014-0555'},
#              '94603': {'94603'},
#              '94305-6015': {'94305-6015'},
#              '95014-0240': {'95014-0240'},
#              '95014-1360': {'95014-1360'},
#              '95014-1334': {'95014-1334'},
#              '95014-1337': {'95014-1337'},
#              '95014-1335': {'95014-1335'},
#              '95014-1361': {'95014-1361'},
#              '94087\u200e': {'94087\u200e'},
#              '95014-5947': {'95014-5947'},
#              '95014-5909': {'95014-5909'},
#              '95014-4229': {'95014-4229'},
#              '95014-5321': {'95014-5321'},
#              '95014-5301': {'95014-5301'},
#              '95134-1358': {'95134-1358'},
#              '95014-4630': {'95014-4630'},
#              '94087-2248': {'94087-2248'},
#              '95014-2058': {'95014-2058'},
#              '9404': {'9404'},
#              '94305;94309': {'94305;94309'},
#              '95086': {'95086'},
#              '94043-3421': {'94043-3421'},
#              '94807': {'94807'},
#              '95014-396': {'95014-396'},
#              '30188': {'30188'},
#              '95014-0202': {'95014-0202'},
#              '95014-0111': {'95014-0111'},
#              '95014-3356': {'95014-3356'},
#              '95014-3313': {'95014-3313'},
#              '95014-2218': {'95014-2218'},
#              '95014-2081': {'95014-2081'},
#              '95014-2040': {'95014-2040'},
#              '95014-2389': {'95014-2389'},
#              '95014-1911': {'95014-1911'},
#              '95014-2176': {'95014-2176'},
#              '95014-5225': {'95014-5225'},
#              '94085-3010': {'94085-3010'},
#              '95112-5005': {'95112-5005'},
#              '95014-2902': {'95014-2902'},
#              '95014-2903': {'95014-2903'},
#              '95014-2922': {'95014-2922'},
#              '95014-2904': {'95014-2904'},
#              '95014-2940': {'95014-2940'},
#              '95014-2945': {'95014-2945'},
#              '95014-2944': {'95014-2944'},
#              '95014-3566': {'95014-3566'},
#              '95014-3500': {'95014-3500'},
#              '95014-3504': {'95014-3504'},
#              '95014-0292': {'95014-0292'},
#              '95014-2937': {'95014-2937'},
#              '95014-2906': {'95014-2906'},
#              '95014-2925': {'95014-2925'},
#              '95014-2971': {'95014-2971'},
#              '95014-2970': {'95014-2970'},
#              '95014-2962': {'95014-2962'},
#              '95014-2928': {'95014-2928'},
#              '95014-3533': {'95014-3533'},
#              '95014-3501': {'95014-3501'},
#              '95014-3532': {'95014-3532'},
#              '95014-3622': {'95014-3622'},
#              '95014-3834': {'95014-3834'},
#              '95014-3506': {'95014-3506'},
#              '95014-3535': {'95014-3535'},
#              '95014-3650': {'95014-3650'},
#              '95014-3816': {'95014-3816'},
#              '95014-3815': {'95014-3815'},
#              '95014-3842': {'95014-3842'},
#              '95014-3841': {'95014-3841'},
#              '95014-3649': {'95014-3649'},
#              '95014-3527': {'95014-3527'},
#              '95014-3659': {'95014-3659'},
#              '95014-3604': {'95014-3604'},
#              '95014-3505': {'95014-3505'},
#              '95014-3507': {'95014-3507'},
#              '95014-3605': {'95014-3605'},
#              '95014-3555': {'95014-3555'},
#              '95014-3844': {'95014-3844'},
#              '95014-3509': {'95014-3509'},
#              '95014-3817': {'95014-3817'},
#              '95014-4612': {'95014-4612'},
#              '95014-3513': {'95014-3513'},
#              '95014-3843': {'95014-3843'},
#              '95014-3866': {'95014-3866'},
#              '95014-3514': {'95014-3514'},
#              '95014-3628': {'95014-3628'},
#              '95014-3652': {'95014-3652'},
#              '95014-3607': {'95014-3607'},
#              '95014-3606': {'95014-3606'},
#              '95014-3651': {'95014-3651'},
#              '95014-3612': {'95014-3612'},
#              '95014-3613': {'95014-3613'},
#              '95014-3876': {'95014-3876'},
#              '95014-3878': {'95014-3878'},
#              '95014-3616': {'95014-3616'},
#              '95014-3845': {'95014-3845'},
#              '95014-3846': {'95014-3846'},
#              '95014-3609': {'95014-3609'},
#              '95014-3818': {'95014-3818'},
#              '95014-3615': {'95014-3615'},
#              '95014-3515': {'95014-3515'},
#              '95014-3819': {'95014-3819'},
#              '95014-3614': {'95014-3614'},
#              '95014-3559': {'95014-3559'},
#              '95014-3561': {'95014-3561'},
#              '95014-4600': {'95014-4600'},
#              '95014-3563': {'95014-3563'},
#              '95014-3848': {'95014-3848'},
#              '95014-3608': {'95014-3608'},
#              '95014-3849': {'95014-3849'},
#              '95014-3847': {'95014-3847'},
#              '95014-6400': {'95014-6400'},
#              '95014-3877': {'95014-3877'},
#              '95014-3680': {'95014-3680'},
#              '95014-6401': {'95014-6401'},
#              '95014-3879': {'95014-3879'},
#              '95014-3681': {'95014-3681'},
#              '95014-3851': {'95014-3851'},
#              '95014-3820': {'95014-3820'},
#              '95014-3850': {'95014-3850'},
#              '95014-3885': {'95014-3885'},
#              '95014-641': {'95014-641'},
#              '95014-6402': {'95014-6402'},
#              '95014-6403': {'95014-6403'},
#              '95014-6404': {'95014-6404'},
#              '95014-6406': {'95014-6406'},
#              '95014-6405': {'95014-6405'},
#              '95014-6408': {'95014-6408'},
#              '95014-6409': {'95014-6409'},
#              '95014-6410': {'95014-6410'},
#              '95014-6411': {'95014-6411'},
#              '95014-6407': {'95014-6407'},
#              '95014-3802': {'95014-3802'},
#              '95014-3810': {'95014-3810'},
#              '95014-3873': {'95014-3873'},
#              '95014-3860': {'95014-3860'},
#              '95014-3883': {'95014-3883'},
#              '95014-3881': {'95014-3881'},
#              '95014-3874': {'95014-3874'},
#              '95014-3852': {'95014-3852'},
#              '95014-3853': {'95014-3853'},
#              '95014-3855': {'95014-3855'},
#              '95014-3854': {'95014-3854'},
#              '95014-3804': {'95014-3804'},
#              '95014-3619': {'95014-3619'},
#              '95014-3624': {'95014-3624'},
#              '95014-3875': {'95014-3875'},
#              '95014-3868': {'95014-3868'},
#              '95014-3882': {'95014-3882'},
#              '95014-3626': {'95014-3626'},
#              '95014-3602': {'95014-3602'},
#              '95014-3621': {'95014-3621'},
#              '95014-3620': {'95014-3620'},
#              '95014-3625': {'95014-3625'},
#              ...})

# %% [markdown]
# ## Part II --  Importing to SQL Database

# %%
# Note: The schema is stored in a .py file in order to take advantage of the
# int() and float() type coercion functions. Otherwise it could easily stored as
# as JSON or another serialized format.

schema = {
    'node': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'lat': {'required': True, 'type': 'float', 'coerce': float},
            'lon': {'required': True, 'type': 'float', 'coerce': float},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'node_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    },
    'way': {
        'type': 'dict',
        'schema': {
            'id': {'required': True, 'type': 'integer', 'coerce': int},
            'user': {'required': True, 'type': 'string'},
            'uid': {'required': True, 'type': 'integer', 'coerce': int},
            'version': {'required': True, 'type': 'string'},
            'changeset': {'required': True, 'type': 'integer', 'coerce': int},
            'timestamp': {'required': True, 'type': 'string'}
        }
    },
    'way_nodes': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'node_id': {'required': True, 'type': 'integer', 'coerce': int},
                'position': {'required': True, 'type': 'integer', 'coerce': int}
            }
        }
    },
    'way_tags': {
        'type': 'list',
        'schema': {
            'type': 'dict',
            'schema': {
                'id': {'required': True, 'type': 'integer', 'coerce': int},
                'key': {'required': True, 'type': 'string'},
                'value': {'required': True, 'type': 'string'},
                'type': {'required': True, 'type': 'string'}
            }
        }
    }
}

# %%
import csv
import codecs
import re
import xml.etree.cElementTree as ET
from unittest import TestCase

import cerberus
import schema


NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema.schema

NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  
    

########################
# my code goes here 
#######################

    # parse the element as node
    if element.tag == 'node':
        
        # parse node child element
        for child_element in element:
            
            node_tag = {}
            
            # if matches problematic re pattern, skip. note: we only have 25 problematic records so it's safe to dump them
            if PROBLEMCHARS.match(child_element.attrib['k']):
                continue
            # if matches lower case with colon re pattern, we store first part of attribte as "type" and second part as "key"
            elif LOWER_COLON.match(child_element.attrib['k']):
                node_tag['type'] = child_element.attrib['k'].split(':',1)[0]
                node_tag['key'] = child_element.attrib['k'].split(':',1)[1]
                node_tag['id'] = element.attrib['id']
                node_tag['value'] = child_element.attrib['v']
                tags.append(node_tag)
            # if no matches, we store regular as "type" and attribute as "key"
            else:
                node_tag['type'] = 'regular'
                node_tag['key'] = child_element.attrib['k']
                node_tag['id'] = element.attrib['id']
                node_tag['value'] = child_element.attrib['v']
                tags.append(node_tag)
        
        # only populates the node_attribs if its value appears in NODE_FIELDS
        for val in element.attrib:
            if val in NODE_FIELDS:
                node_attribs[val] = element.attrib[val]
        
        # return parsed node
        return {'node': node_attribs, 'node_tags': tags}
    
    # parse the element as way    
    elif element.tag == 'way':
        
        node_position = 0
        
        for child_element in element:
            
            way_tag = {}
            way_node = {}
            
            if child_element.tag == 'tag':
                # if matches problematic re pattern, skip. note: we only have 25 problematic records so it's safe to dump them
                if PROBLEMCHARS.match(child_element.attrib['k']):
                    continue
                # if matches lower case with colon re pattern, we store first part of attribte as "type" and second part as "key"
                elif LOWER_COLON.match(child_element.attrib['k']):
                    way_tag['type'] = child_element.attrib['k'].split(':',1)[0]
                    way_tag['key'] = child_element.attrib['k'].split(':',1)[1]
                    way_tag['id'] = element.attrib['id']
                    way_tag['value'] = child_element.attrib['v']
                    tags.append(way_tag)
                # if no matches, we store regular as "type" and attribute as "key"
                else:
                    way_tag['type'] = 'regular'
                    way_tag['key'] = child_element.attrib['k']
                    way_tag['id'] = element.attrib['id']
                    way_tag['value'] = child_element.attrib['v']
                    tags.append(way_tag)
                    
            elif child_element.tag == 'nd':
                way_node['id'] = element.attrib['id']
                way_node['node_id'] = child_element.attrib['ref']
                way_node['position'] = node_position
                node_position = node_position + 1
                way_nodes.append(way_node)
        
        # only populates the way_attribs if its value appears in WAY_FIELDS
        for val in element.attrib:
            if val in WAY_FIELDS:
                way_attribs[val] = element.attrib[val]
                
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}


# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.items())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_strings = (
            "{0}: {1}".format(k, v if isinstance(v, unicode) else ", ".join(v))
            for k, v in errors.items()
        )
        raise cerberus.ValidationError(
            message_string.format(field, "\n".join(error_strings))
        )

# unicode is deprecated in Python 3, this gives me so much trouble...!!! I managed to resolve this problem by changing "unicode" to "str"
class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v if isinstance(v, str) else v) for k, v in row.items()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w', encoding='utf-8') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w', encoding='utf-8') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w', encoding='utf-8') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w', encoding='utf-8') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w', encoding='utf-8') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    process_map(DATA, validate=True)

# %%
import sqlite3
import csv 

con = sqlite3.connect("sunnyvale.db")
con.text_factory = str
cur = con.cursor()

# Drop the tables if they already exist....

# cur.execute("DROP TABLE nodes")
# cur.execute("DROP TABLE nodes_tags")
# cur.execute("DROP TABLE ways")
# cur.execute("DROP TABLE ways_nodes")
# cur.execute("DROP TABLE ways_tags")

# create nodes table
cur.execute("CREATE TABLE nodes (id, lat, lon, user, uid, version, changeset, timestamp);")
with open('nodes.csv','rt') as fin:
    dr = csv.DictReader(fin) 
    to_db = [(i['id'], i['lat'], i['lon'], i['user'], i['uid'], i['version'], i['changeset'], i['timestamp']) \
             for i in dr]

cur.executemany("INSERT INTO nodes (id, lat, lon, user, uid, version, changeset, timestamp) \
                VALUES (?, ?, ?, ?, ?, ?, ?, ?);", to_db)
con.commit()

# create nodes_tags table
cur.execute("CREATE TABLE nodes_tags (id, key, value, type);")
# read csv as "text" file
with open('nodes_tags.csv','rt') as fin:
    dr = csv.DictReader(fin) 
    to_db = [(i['id'], i['key'], i['value'], i['type']) for i in dr]

cur.executemany("INSERT INTO nodes_tags (id, key, value, type) VALUES (?, ?, ?, ?);", to_db)
con.commit()

# create ways table
cur.execute("CREATE TABLE ways (id, user, uid, version, changeset, timestamp);")
# read csv as "text" file
with open('ways.csv','rt') as fin:
    dr = csv.DictReader(fin) 
    to_db = [(i['id'], i['user'], i['uid'], i['version'], i['changeset'], i['timestamp']) for i in dr]

cur.executemany("INSERT INTO ways (id, user, uid, version, changeset, timestamp) VALUES (?, ?, ?, ?, ?, ?);", to_db)
con.commit()

# create ways_nodes table
cur.execute("CREATE TABLE ways_nodes (id, node_id, position);")
# read csv as "text" file
with open('ways_nodes.csv','rt') as fin:
    dr = csv.DictReader(fin) 
    to_db = [(i['id'], i['node_id'], i['position']) for i in dr]

cur.executemany("INSERT INTO ways_nodes (id, node_id, position) VALUES (?, ?, ?);", to_db)
con.commit()

# create ways_tags table
cur.execute("CREATE TABLE ways_tags (id, key, value, type);")
# read csv as "text" file
with open('ways_tags.csv','rt') as fin:
    dr = csv.DictReader(fin) 
    to_db = [(i['id'], i['key'], i['value'], i['type']) for i in dr]

cur.executemany("INSERT INTO ways_tags (id, key, value, type) VALUES (?, ?, ?, ?);", to_db)
con.commit()

# %%
# Create the SQL database
conn = sqlite3.connect('Sunnyvale.db')
cursor = conn.cursor()
query = '''SELECT * FROM nodes LIMIT 5;'''
cursor.execute(query)
all_rows = cursor.fetchall()
print(all_rows)
# Out:
# [('302863', '37.3769826', '-122.0677726', 'KindredCoda', '14293', '4', '6776161', '2010-12-27T10:41:10Z'), ('302864', '37.3740667', '-122.0679336', 'KindredCoda', '14293', '5', '6776161', '2010-12-27T10:39:22Z'), ('302865', '37.3733004', '-122.0677211', 'KindredCoda', '14293', '4', '6774664', '2010-12-27T07:44:11Z'), ('302866', '37.3725970', '-122.0673831', 'KindredCoda', '14293', '4', '6774664', '2010-12-27T07:43:52Z'), ('302867', '37.3695957', '-122.0655646', 'KindredCoda', '14293', '4', '6774664', '2010-12-27T07:43:25Z')]

# %% [markdown]
# ##  Data Overview

# %%
import os
print('Sunnyvale.osm file is {} MB'.format(os.path.getsize('DATA')/1.0e6))
print('The project.db file is {} MB'.format(os.path.getsize('Sunnyvale.db')/1.0e6))
print('The nodes.csv file is {} MB'.format(os.path.getsize('nodes.csv')/1.0e6))
print('The nodes_tags.csv file is {} MB'.format(os.path.getsize('nodes.csv')/1.0e6))
print('The ways.csv file is {} MB'.format(os.path.getsize('ways.csv')/1.0e6))
print('The ways_tags.csv is {} MB'.format(os.path.getsize('ways_tags.csv')/1.0e6))
print('The ways_nodes.csv is {} MB'.format(os.path.getsize('ways_nodes.csv')/1.0e6)) # Convert from bytes to MB
# Out:
# Sunnyvale.osm file is 575.870831 MB
# The project.db file is 398.548992 MB
# The nodes.csv file is 218.36976 MB
# The nodes_tags.csv file is 218.36976 MB
# The ways.csv file is 20.115894 MB
# The ways_tags.csv is 33.379364 MB
# The ways_nodes.csv is 72.495658 MB
